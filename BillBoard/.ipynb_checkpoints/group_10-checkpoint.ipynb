# %%
class BillboardItem(scrapy.Item):
    # define the fields for your item here like:
        rank = scrapy.Field()
        img = scrapy.Field()
        title = scrapy.Field()
        singer = scrapy.Field()
        last_position = scrapy.Field()
        peak_position = scrapy.Field()
        weaks_on_charts = scrapy.Field()
        name = scrapy.Field()

# %%
import scrapy
from scrapy import Request
from BillBoard.items import BillboardItem

class BillboardSpider(scrapy.Spider):
    name = 'billBoard'
    allowed_domains = ['www.billboard.com']
    start_urls = ['https://www.billboard.com/charts/billboard-global-200/','https://www.billboard.com/charts/r-and-b-songs/','https://www.billboard.com/charts/hot-100/','https://www.billboard.com/charts/rap-song/']

    def start_requests(self):
        for url in self.start_urls:
            yield Request(url=url, callback=self.parse_song)

    def parse_song(self, response):
        liste_song = response.css('.o-chart-results-list-row-container')
        
        for song in liste_song:
            item = BillboardItem()
            
            #name
            try:
                item['name'] = response.css('div.chart-results h2::text')[0].extract().strip()
            except:
                item['name'] = 'None'
            
            # Rank de la musique
            try:
                item['rank'] = song.css('li.o-chart-results-list__item span::text')[0].extract().strip()
            except:
                item['rank'] = 'None'
                
            # img de la musique
            try:
                item['img'] = song.css('li.o-chart-results-list__item img.c-lazy-image__img.lrv-u-background-color-grey-lightest.lrv-u-width-100p.lrv-u-display-block.lrv-u-height-auto').attrib['data-lazy-src']
            except:
                item['img'] = 'None'
            
            # title de la musique
            try:
                item['title'] = song.css('li.o-chart-results-list__item h3::text')[0].extract().strip()
            except:
                item['title'] = 'None'
        
            # singer de la musique
            try:
                item['singer'] = song.css('li.lrv-u-width-100p span.c-label::text').get().strip()
            except:
                item['singer'] = 'None'
            
               # Dernière position au classement de la musique
            try:
                item['last_position'] = song.css('li.o-chart-results-list__item .c-label.a-font-primary-bold-l::text')[0].extract().strip()
            except:
                item['last_position'] = song.css('li.o-chart-results-list__item .c-label.a-font-primary-m::text')[0].extract().strip()
               
            # Meilleur position au classement de la musique
            try:
                item['peak_position'] = song.css('li.o-chart-results-list__item .c-label.a-font-primary-bold-l::text')[1].extract().strip()
            except:
                item['peak_position'] = song.css('li.o-chart-results-list__item .c-label.a-font-primary-m::text')[1].extract().strip()
                
            # Durée dans le classement
            try:
                item['weaks_on_charts'] = song.css('li.o-chart-results-list__item .c-label.a-font-primary-bold-l::text')[2].extract().strip()
            except:
                item['weaks_on_charts'] = song.css('li.o-chart-results-list__item .c-label.a-font-primary-m::text')[2].extract().strip()
        
            yield item

# %%
# !cd BillBoard/spiders && scrapy crawl billBoard -o billboard.csv
# Out:
# 2022-10-20 15:22:20 [scrapy.utils.log] INFO: Scrapy 2.7.0 started (bot: BillBoard)
# 2022-10-20 15:22:20 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.8.0, Python 3.8.10 (default, Jun 22 2022, 20:18:18) - [GCC 9.4.0], pyOpenSSL 22.1.0 (OpenSSL 3.0.5 5 Jul 2022), cryptography 38.0.1, Platform Linux-5.15.0-50-generic-x86_64-with-glibc2.29
# 2022-10-20 15:22:20 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'BillBoard',
#  'NEWSPIDER_MODULE': 'BillBoard.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['BillBoard.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2022-10-20 15:22:20 [asyncio] DEBUG: Using selector: EpollSelector
# 2022-10-20 15:22:20 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2022-10-20 15:22:20 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2022-10-20 15:22:20 [scrapy.extensions.telnet] INFO: Telnet Password: e4cb1ce219e57904
# 2022-10-20 15:22:20 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2022-10-20 15:22:20 [py.warnings] WARNING: /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
#
# 2022-10-20 15:22:20 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-10-20 15:22:20 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-10-20 15:22:20 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-10-20 15:22:20 [scrapy.core.engine] INFO: Spider opened
# 2022-10-20 15:22:20 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-10-20 15:22:20 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2022-10-20 15:22:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.billboard.com/robots.txt> (referer: None)
# 2022-10-20 15:22:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.billboard.com/charts/billboard-global-200/> (referer: None)
# 2022-10-20 15:22:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.billboard.com/charts/r-and-b-songs/> (referer: None)
# 2022-10-20 15:22:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.billboard.com/charts/hot-100/> (referer: None)
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/10/sam-smith-0od-unholy-dry-180x180.jpg',
#  'last_position': '1',
#  'name': 'Billboard Global 200',
#  'peak_position': '1',
#  'rank': '1',
#  'singer': 'Sam Smith & Kim Petras',
#  'title': 'Unholy',
#  'weaks_on_charts': '1'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/09/david-guetta-ruw-imgoodblue-rkt-180x180.jpg',
#  'last_position': '2',
#  'name': 'Billboard Global 200',
#  'peak_position': '2',
#  'rank': '2',
#  'singer': 'David Guetta & Bebe Rexha',
#  'title': "I'm Good (Blue)",
#  'weaks_on_charts': '7'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/04/harry-styles-6jk-asitwas-frn-180x180.jpg',
#  'last_position': '3',
#  'name': 'Billboard Global 200',
#  'peak_position': '1',
#  'rank': '3',
#  'singer': 'Harry Styles',
#  'title': 'As It Was',
#  'weaks_on_charts': '28'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2005/07/chris-brown-94g-180x180.jpg',
#  'last_position': '4',
#  'name': 'Billboard Global 200',
#  'peak_position': '4',
#  'rank': '4',
#  'singer': 'Chris Brown',
#  'title': 'Under The Influence',
#  'weaks_on_charts': '12'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/06/onerepublic-m2z-i-aint-worried-6ds-180x180.jpg',
#  'last_position': '5',
#  'name': 'Billboard Global 200',
#  'peak_position': '5',
#  'rank': '5',
#  'singer': 'OneRepublic',
#  'title': "I Ain't Worried",
#  'weaks_on_charts': '19'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/06/manuel-turizo-eml-la-bachata-1l6-180x180.jpg',
#  'last_position': '6',
#  'name': 'Billboard Global 200',
#  'peak_position': '6',
#  'rank': '6',
#  'singer': 'Manuel Turizo',
#  'title': 'La Bachata',
#  'weaks_on_charts': '14'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/steve-lacy-d2o-badhabit-l6b-180x180.jpg',
#  'last_position': '1',
#  'name': 'Hot R&B Songs',
#  'peak_position': '1',
#  'rank': '1',
#  'singer': 'Steve Lacy',
#  'title': 'Bad Habit',
#  'weaks_on_charts': '1'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/steve-lacy-d2o-badhabit-l6b-180x180.jpg',
#  'last_position': '1',
#  'name': 'Billboard Hot 100',
#  'peak_position': '1',
#  'rank': '1',
#  'singer': 'Steve Lacy',
#  'title': 'Bad Habit',
#  'weaks_on_charts': '1'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/bad-bunny-c3m-180x180.jpg',
#  'last_position': '7',
#  'name': 'Billboard Global 200',
#  'peak_position': '2',
#  'rank': '7',
#  'singer': 'Bad Bunny & Chencho Corleone',
#  'title': 'Me Porto Bonito',
#  'weaks_on_charts': '23'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2022/04/lizzo-o9x-about-damn-time-f6q-180x180.jpg',
#  'last_position': '2',
#  'name': 'Hot R&B Songs',
#  'peak_position': '1',
#  'rank': '2',
#  'singer': 'Lizzo',
#  'title': 'About Damn Time',
#  'weaks_on_charts': '26'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2005/07/chris-brown-94g-180x180.jpg',
#  'last_position': '3',
#  'name': 'Hot R&B Songs',
#  'peak_position': '3',
#  'rank': '3',
#  'singer': 'Chris Brown',
#  'title': 'Under The Influence',
#  'weaks_on_charts': '6'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2002/06/beyonce-0na-180x180.jpg',
#  'last_position': '4',
#  'name': 'Hot R&B Songs',
#  'peak_position': '4',
#  'rank': '4',
#  'singer': 'Beyonce',
#  'title': 'Cuff It',
#  'weaks_on_charts': '11'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2016/12/the-weeknd-xmx-dieforyou-eei-180x180.jpg',
#  'last_position': '5',
#  'name': 'Hot R&B Songs',
#  'peak_position': '5',
#  'rank': '5',
#  'singer': 'The Weeknd',
#  'title': 'Die For You',
#  'weaks_on_charts': '40'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/10/sam-smith-0od-unholy-7a7-180x180.jpg',
#  'last_position': '2',
#  'name': 'Billboard Hot 100',
#  'peak_position': '2',
#  'rank': '2',
#  'singer': 'Sam Smith & Kim Petras',
#  'title': 'Unholy',
#  'weaks_on_charts': '3'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/04/harry-styles-6jk-asitwas-po3-180x180.jpg',
#  'last_position': '3',
#  'name': 'Billboard Hot 100',
#  'peak_position': '1',
#  'rank': '3',
#  'singer': 'Harry Styles',
#  'title': 'As It Was',
#  'weaks_on_charts': '28'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/bad-bunny-c3m-180x180.jpg',
#  'last_position': '8',
#  'name': 'Billboard Global 200',
#  'peak_position': '4',
#  'rank': '8',
#  'singer': 'Bad Bunny',
#  'title': 'Titi Me Pregunto',
#  'weaks_on_charts': '23'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2021/05/tems-67h-180x180.jpg',
#  'last_position': '6',
#  'name': 'Hot R&B Songs',
#  'peak_position': '4',
#  'rank': '6',
#  'singer': 'Tems',
#  'title': 'Free Mind',
#  'weaks_on_charts': '38'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/beyonce-0na-break-my-soul-kqf-180x180.jpg',
#  'last_position': '7',
#  'name': 'Hot R&B Songs',
#  'peak_position': '1',
#  'rank': '7',
#  'singer': 'Beyonce',
#  'title': 'Break My Soul',
#  'weaks_on_charts': '17'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2016/07/brent-faiyaz-cg6-180x180.jpg',
#  'last_position': '8',
#  'name': 'Hot R&B Songs',
#  'peak_position': '3',
#  'rank': '8',
#  'singer': 'Brent Faiyaz',
#  'title': 'All Mine',
#  'weaks_on_charts': '14'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2021/08/steve-lacy-d2o-darkred-md5-180x180.jpg',
#  'last_position': '9',
#  'name': 'Hot R&B Songs',
#  'peak_position': '9',
#  'rank': '9',
#  'singer': 'Steve Lacy',
#  'title': 'Dark Red',
#  'weaks_on_charts': '5'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2015/06/post-malone-8b5-180x180.jpg',
#  'last_position': '4',
#  'name': 'Billboard Hot 100',
#  'peak_position': '3',
#  'rank': '4',
#  'singer': 'Post Malone Featuring Doja Cat',
#  'title': 'I Like You (A Happier Song)',
#  'weaks_on_charts': '19'}
# 2022-10-20 15:22:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/05/morgan-wallen-nlu-you-proof-uu4-180x180.jpg',
#  'last_position': '5',
#  'name': 'Billboard Hot 100',
#  'peak_position': '5',
#  'rank': '5',
#  'singer': 'Morgan Wallen',
#  'title': 'You Proof',
#  'weaks_on_charts': '22'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/bizarrap-rsm-bzrp-music-sessions-vol-52-6r7-180x180.jpg',
#  'last_position': '9',
#  'name': 'Billboard Global 200',
#  'peak_position': '1',
#  'rank': '9',
#  'singer': 'Bizarrap & Quevedo',
#  'title': 'Bzrp Music Sessions, Vol. 52',
#  'weaks_on_charts': '14'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2016/12/steve-lacy-d2o-180x180.jpg',
#  'last_position': '10',
#  'name': 'Hot R&B Songs',
#  'peak_position': '8',
#  'rank': '10',
#  'singer': 'Steve Lacy',
#  'title': 'Static',
#  'weaks_on_charts': '11'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2022/06/diddy-v7r-gotta-move-on-546-180x180.jpg',
#  'last_position': '11',
#  'name': 'Hot R&B Songs',
#  'peak_position': '7',
#  'rank': '11',
#  'singer': 'Diddy & Bryson Tiller',
#  'title': 'Gotta Move On',
#  'weaks_on_charts': '15'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2011/06/tory-lanez-i88-180x180.jpg',
#  'last_position': '12',
#  'name': 'Hot R&B Songs',
#  'peak_position': '12',
#  'rank': '12',
#  'singer': 'Tory Lanez',
#  'title': 'The Color Violet',
#  'weaks_on_charts': '8'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2010/10/kendrick-lamar-atc-180x180.jpg',
#  'last_position': '13',
#  'name': 'Hot R&B Songs',
#  'peak_position': '1',
#  'rank': '13',
#  'singer': 'Kendrick Lamar, Blxst & Amanda Reifer',
#  'title': 'Die Hard',
#  'weaks_on_charts': '22'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/06/onerepublic-m2z-i-aint-worried-p2t-180x180.jpg',
#  'last_position': '6',
#  'name': 'Billboard Hot 100',
#  'peak_position': '6',
#  'rank': '6',
#  'singer': 'OneRepublic',
#  'title': "I Ain't Worried",
#  'weaks_on_charts': '18'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/02/nicky-youre-alv-sunroof-3kv-180x180.jpg',
#  'last_position': '7',
#  'name': 'Billboard Hot 100',
#  'peak_position': '4',
#  'rank': '7',
#  'singer': 'Nicky Youre & dazy',
#  'title': 'Sunroof',
#  'weaks_on_charts': '20'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/steve-lacy-d2o-badhabit-9nj-180x180.jpg',
#  'last_position': '10',
#  'name': 'Billboard Global 200',
#  'peak_position': '10',
#  'rank': '10',
#  'singer': 'Steve Lacy',
#  'title': 'Bad Habit',
#  'weaks_on_charts': '14'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2022/10/hotelugly-000-shutupmymomscalling-l92-180x180.jpg',
#  'last_position': '14',
#  'name': 'Hot R&B Songs',
#  'peak_position': '14',
#  'rank': '14',
#  'singer': 'Hotel Ugly',
#  'title': 'Shut Up My Moms Calling',
#  'weaks_on_charts': '2'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2022/10/montellfish-8r8-hotel-1ve-180x180.jpg',
#  'last_position': '15',
#  'name': 'Hot R&B Songs',
#  'peak_position': '13',
#  'rank': '15',
#  'singer': 'Montell Fish',
#  'title': 'Hotel',
#  'weaks_on_charts': '4'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2021/01/mariah-the-scientist-9tr-180x180.jpg',
#  'last_position': '16',
#  'name': 'Hot R&B Songs',
#  'peak_position': '16',
#  'rank': '16',
#  'singer': 'Mariah The Scientist',
#  'title': 'Spread Thin',
#  'weaks_on_charts': '2'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2002/06/beyonce-0na-180x180.jpg',
#  'last_position': '17',
#  'name': 'Hot R&B Songs',
#  'peak_position': '4',
#  'rank': '17',
#  'singer': 'Beyonce',
#  'title': 'Alien Superstar',
#  'weaks_on_charts': '11'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/08/nicki-minaj-721-superfreakygirl-wpa-180x180.jpg',
#  'last_position': '8',
#  'name': 'Billboard Hot 100',
#  'peak_position': '1',
#  'rank': '8',
#  'singer': 'Nicki Minaj',
#  'title': 'Super Freaky Girl',
#  'weaks_on_charts': '9'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/06/luke-combs-9dm-the-kind-of-love-we-make-oo9-180x180.jpg',
#  'last_position': '9',
#  'name': 'Billboard Hot 100',
#  'peak_position': '8',
#  'rank': '9',
#  'singer': 'Luke Combs',
#  'title': 'The Kind Of Love We Make',
#  'weaks_on_charts': '17'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/04/rema-000-calmdown-55o-180x180.jpg',
#  'last_position': '11',
#  'name': 'Billboard Global 200',
#  'peak_position': '11',
#  'rank': '11',
#  'singer': 'Rema & Selena Gomez',
#  'title': 'Calm Down',
#  'weaks_on_charts': '15'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/chris-brown-94g-callmeeveryday-k3v-180x180.jpg',
#  'last_position': '18',
#  'name': 'Hot R&B Songs',
#  'peak_position': '4',
#  'rank': '18',
#  'singer': 'Chris Brown Featuring WizKid',
#  'title': 'Call Me Everyday',
#  'weaks_on_charts': '17'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2011/09/thundercat-u6f-180x180.jpg',
#  'last_position': '19',
#  'name': 'Hot R&B Songs',
#  'peak_position': '19',
#  'rank': '19',
#  'singer': 'Thundercat',
#  'title': 'Them Changes',
#  'weaks_on_charts': '1'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2014/04/sza-8os-180x180.jpg',
#  'last_position': '20',
#  'name': 'Hot R&B Songs',
#  'peak_position': '17',
#  'rank': '20',
#  'singer': 'SZA',
#  'title': 'Awkward',
#  'weaks_on_charts': '7'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2022/08/ronald-isley-msk-makemesayitagaingirl-axj-180x180.jpg',
#  'last_position': '21',
#  'name': 'Hot R&B Songs',
#  'peak_position': '21',
#  'rank': '21',
#  'singer': 'Ronald Isley, Beyonce & The Isley Brothers',
#  'title': 'Make Me Say It Again Girl',
#  'weaks_on_charts': '3'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/05/doja-cat-lm6-vegas-w90-180x180.jpg',
#  'last_position': '10',
#  'name': 'Billboard Hot 100',
#  'peak_position': '10',
#  'rank': '10',
#  'singer': 'Doja Cat',
#  'title': 'Vegas',
#  'weaks_on_charts': '19'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/04/lizzo-o9x-about-damn-time-f6q-180x180.jpg',
#  'last_position': '11',
#  'name': 'Billboard Hot 100',
#  'peak_position': '1',
#  'rank': '11',
#  'singer': 'Lizzo',
#  'title': 'About Damn Time',
#  'weaks_on_charts': '26'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2002/06/beyonce-0na-180x180.jpg',
#  'last_position': '12',
#  'name': 'Billboard Global 200',
#  'peak_position': '12',
#  'rank': '12',
#  'singer': 'Beyonce',
#  'title': 'Cuff It',
#  'weaks_on_charts': '11'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/08/blackpink-l5z-180x180.jpg',
#  'last_position': '13',
#  'name': 'Billboard Global 200',
#  'peak_position': '1',
#  'rank': '13',
#  'singer': 'BLACKPINK',
#  'title': 'Shut Down',
#  'weaks_on_charts': '4'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2016/12/ella-mai-4oz-180x180.jpg',
#  'last_position': '22',
#  'name': 'Hot R&B Songs',
#  'peak_position': '14',
#  'rank': '22',
#  'singer': 'Ella Mai Featuring Roddy Ricch',
#  'title': 'How',
#  'weaks_on_charts': '15'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2021/03/silk-sonic-bruno-mars-and-anderson-paak-qd5-180x180.jpg',
#  'last_position': '23',
#  'name': 'Hot R&B Songs',
#  'peak_position': '8',
#  'rank': '23',
#  'singer': 'Silk Sonic (Bruno Mars & Anderson .Paak) With Thundercat & Bootsy '
#            'Collins',
#  'title': 'After Last Night',
#  'weaks_on_charts': '4'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2002/06/beyonce-0na-180x180.jpg',
#  'last_position': '24',
#  'name': 'Hot R&B Songs',
#  'peak_position': '8',
#  'rank': '24',
#  'singer': 'Beyonce Featuring BEAM',
#  'title': 'Energy',
#  'weaks_on_charts': '11'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/r-and-b-songs/>
# {'img': 'https://charts-static.billboard.com/img/2020/03/giveon-k6h-180x180.jpg',
#  'last_position': '25',
#  'name': 'Hot R&B Songs',
#  'peak_position': '8',
#  'rank': '25',
#  'singer': 'Giveon',
#  'title': 'Lost Me',
#  'weaks_on_charts': '16'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/05/zach-bryan-cfd-something-in-the-orange-ynj-180x180.jpg',
#  'last_position': '12',
#  'name': 'Billboard Hot 100',
#  'peak_position': '12',
#  'rank': '12',
#  'singer': 'Zach Bryan',
#  'title': 'Something In The Orange',
#  'weaks_on_charts': '25'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/1988/03/future-f8b-180x180.jpg',
#  'last_position': '13',
#  'name': 'Billboard Hot 100',
#  'peak_position': '1',
#  'rank': '13',
#  'singer': 'Future Featuring Drake & Tems',
#  'title': 'Wait For U',
#  'weaks_on_charts': '24'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/08/nicki-minaj-721-superfreakygirl-y5e-180x180.jpg',
#  'last_position': '14',
#  'name': 'Billboard Global 200',
#  'peak_position': '5',
#  'rank': '14',
#  'singer': 'Nicki Minaj',
#  'title': 'Super Freaky Girl',
#  'weaks_on_charts': '9'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2021/01/morgan-wallen-nlu-wasted-on-you-32x-180x180.jpg',
#  'last_position': '14',
#  'name': 'Billboard Hot 100',
#  'peak_position': '9',
#  'rank': '14',
#  'singer': 'Morgan Wallen',
#  'title': 'Wasted On You',
#  'weaks_on_charts': '48'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/bad-bunny-c3m-180x180.jpg',
#  'last_position': '15',
#  'name': 'Billboard Hot 100',
#  'peak_position': '5',
#  'rank': '15',
#  'singer': 'Bad Bunny',
#  'title': 'Titi Me Pregunto',
#  'weaks_on_charts': '23'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/08/rosalia-88x-despecha-hsd-180x180.jpg',
#  'last_position': '15',
#  'name': 'Billboard Global 200',
#  'peak_position': '6',
#  'rank': '15',
#  'singer': 'Rosalia',
#  'title': 'Despecha',
#  'weaks_on_charts': '11'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/09/david-guetta-ruw-imgoodblue-d17-180x180.jpg',
#  'last_position': '16',
#  'name': 'Billboard Hot 100',
#  'peak_position': '16',
#  'rank': '16',
#  'singer': 'David Guetta & Bebe Rexha',
#  'title': "I'm Good (Blue)",
#  'weaks_on_charts': '7'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/bad-bunny-c3m-180x180.jpg',
#  'last_position': '17',
#  'name': 'Billboard Hot 100',
#  'peak_position': '6',
#  'rank': '17',
#  'singer': 'Bad Bunny & Chencho Corleone',
#  'title': 'Me Porto Bonito',
#  'weaks_on_charts': '23'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2013/01/tom-odell-qwt-180x180.jpg',
#  'last_position': '16',
#  'name': 'Billboard Global 200',
#  'peak_position': '16',
#  'rank': '16',
#  'singer': 'Tom Odell',
#  'title': 'Another Love',
#  'weaks_on_charts': '76'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/05/harry-styles-6jk-latenighttalking-fzv-180x180.jpg',
#  'last_position': '18',
#  'name': 'Billboard Hot 100',
#  'peak_position': '3',
#  'rank': '18',
#  'singer': 'Harry Styles',
#  'title': 'Late Night Talking',
#  'weaks_on_charts': '21'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/08/glorilla-000-tomorrow2-5ob-180x180.jpg',
#  'last_position': '19',
#  'name': 'Billboard Hot 100',
#  'peak_position': '9',
#  'rank': '19',
#  'singer': 'GloRilla & Cardi B',
#  'title': 'Tomorrow 2',
#  'weaks_on_charts': '3'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/bad-bunny-c3m-180x180.jpg',
#  'last_position': '17',
#  'name': 'Billboard Global 200',
#  'peak_position': '7',
#  'rank': '17',
#  'singer': 'Bad Bunny',
#  'title': 'Efecto',
#  'weaks_on_charts': '23'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2013/06/cole-swindell-2q7-180x180.jpg',
#  'last_position': '20',
#  'name': 'Billboard Hot 100',
#  'peak_position': '16',
#  'rank': '20',
#  'singer': 'Cole Swindell',
#  'title': 'She Had Me At Heads Carolina',
#  'weaks_on_charts': '20'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2020/07/glass-animals-rtd-heat-waves-o3i-180x180.jpg',
#  'last_position': '21',
#  'name': 'Billboard Hot 100',
#  'peak_position': '1',
#  'rank': '21',
#  'singer': 'Glass Animals',
#  'title': 'Heat Waves',
#  'weaks_on_charts': '91'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/09/blackpink-l5z-pinkvenom-t5p-180x180.jpg',
#  'last_position': '18',
#  'name': 'Billboard Global 200',
#  'peak_position': '1',
#  'rank': '18',
#  'singer': 'BLACKPINK',
#  'title': 'Pink Venom',
#  'weaks_on_charts': '8'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2009/04/drake-04g-180x180.jpg',
#  'last_position': '22',
#  'name': 'Billboard Hot 100',
#  'peak_position': '1',
#  'rank': '22',
#  'singer': 'Drake Featuring 21 Savage',
#  'title': 'Jimmy Cooks',
#  'weaks_on_charts': '17'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2005/07/chris-brown-94g-180x180.jpg',
#  'last_position': '23',
#  'name': 'Billboard Hot 100',
#  'peak_position': '23',
#  'rank': '23',
#  'singer': 'Chris Brown',
#  'title': 'Under The Influence',
#  'weaks_on_charts': '5'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2020/07/glass-animals-rtd-heat-waves-1lv-180x180.jpg',
#  'last_position': '19',
#  'name': 'Billboard Global 200',
#  'peak_position': '1',
#  'rank': '19',
#  'singer': 'Glass Animals',
#  'title': 'Heat Waves',
#  'weaks_on_charts': '93'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/09/elton-john-m6x-holdmecloser-952-180x180.jpg',
#  'last_position': '24',
#  'name': 'Billboard Hot 100',
#  'peak_position': '6',
#  'rank': '24',
#  'singer': 'Elton John & Britney Spears',
#  'title': 'Hold Me Closer',
#  'weaks_on_charts': '7'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/05/tylerhubbard-lp0-5foot9-ngv-180x180.jpg',
#  'last_position': '25',
#  'name': 'Billboard Hot 100',
#  'peak_position': '22',
#  'rank': '25',
#  'singer': 'Tyler Hubbard',
#  'title': '5 Foot 9',
#  'weaks_on_charts': '18'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/rosalinn-rc0-snap-c77-180x180.jpg',
#  'last_position': '20',
#  'name': 'Billboard Global 200',
#  'peak_position': '18',
#  'rank': '20',
#  'singer': 'Rosa Linn',
#  'title': 'Snap',
#  'weaks_on_charts': '14'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/09/kane-brown-dqa-thankgod-qyu-180x180.jpg',
#  'last_position': '26',
#  'name': 'Billboard Hot 100',
#  'peak_position': '22',
#  'rank': '26',
#  'singer': 'Kane Brown With Katelyn Brown',
#  'title': 'Thank God',
#  'weaks_on_charts': '5'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2002/06/beyonce-0na-180x180.jpg',
#  'last_position': '27',
#  'name': 'Billboard Hot 100',
#  'peak_position': '13',
#  'rank': '27',
#  'singer': 'Beyonce',
#  'title': 'Cuff It',
#  'weaks_on_charts': '9'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/bad-bunny-c3m-180x180.jpg',
#  'last_position': '21',
#  'name': 'Billboard Global 200',
#  'peak_position': '4',
#  'rank': '21',
#  'singer': 'Bad Bunny & Bomba Estereo',
#  'title': 'Ojitos Lindos',
#  'weaks_on_charts': '23'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2020/12/the-weeknd-xmx-save-your-tears-e5b-180x180.jpg',
#  'last_position': '22',
#  'name': 'Billboard Global 200',
#  'peak_position': '1',
#  'rank': '22',
#  'singer': 'The Weeknd & Ariana Grande',
#  'title': 'Save Your Tears',
#  'weaks_on_charts': '93'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2006/01/sia-0sp-180x180.jpg',
#  'last_position': '28',
#  'name': 'Billboard Hot 100',
#  'peak_position': '28',
#  'rank': '28',
#  'singer': 'Sia',
#  'title': 'Unstoppable',
#  'weaks_on_charts': '15'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/02/baileyzimmerman-qt3-fallinlove-d5q-180x180.jpg',
#  'last_position': '29',
#  'name': 'Billboard Hot 100',
#  'peak_position': '29',
#  'rank': '29',
#  'singer': 'Bailey Zimmerman',
#  'title': 'Fall In Love',
#  'weaks_on_charts': '24'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/05/zach-bryan-cfd-something-in-the-orange-8ma-180x180.jpg',
#  'last_position': '23',
#  'name': 'Billboard Global 200',
#  'peak_position': '23',
#  'rank': '23',
#  'singer': 'Zach Bryan',
#  'title': 'Something In The Orange',
#  'weaks_on_charts': '24'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2018/01/jack-harlow-i43-180x180.jpg',
#  'last_position': '30',
#  'name': 'Billboard Hot 100',
#  'peak_position': '1',
#  'rank': '30',
#  'singer': 'Jack Harlow',
#  'title': 'First Class',
#  'weaks_on_charts': '27'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/06/baileyzimmerman-qt3-rockandahardplace-vms-180x180.jpg',
#  'last_position': '31',
#  'name': 'Billboard Hot 100',
#  'peak_position': '24',
#  'rank': '31',
#  'singer': 'Bailey Zimmerman',
#  'title': 'Rock And A Hard Place',
#  'weaks_on_charts': '18'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/bad-bunny-c3m-180x180.jpg',
#  'last_position': '24',
#  'name': 'Billboard Global 200',
#  'peak_position': '2',
#  'rank': '24',
#  'singer': 'Bad Bunny',
#  'title': 'Moscow Mule',
#  'weaks_on_charts': '23'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/10/lil-nas-x-qv4-starwalkinleagueoflegendsworldsanthem-hbq-180x180.jpg',
#  'last_position': '32',
#  'name': 'Billboard Hot 100',
#  'peak_position': '32',
#  'rank': '32',
#  'singer': 'Lil Nas X',
#  'title': "Star Walkin' (League Of Legends Worlds Anthem)",
#  'weaks_on_charts': '3'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2016/12/the-weeknd-xmx-dieforyou-eei-180x180.jpg',
#  'last_position': '33',
#  'name': 'Billboard Hot 100',
#  'peak_position': '33',
#  'rank': '33',
#  'singer': 'The Weeknd',
#  'title': 'Die For You',
#  'weaks_on_charts': '11'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2013/03/the-neighbourhood-ro9-180x180.jpg',
#  'last_position': '25',
#  'name': 'Billboard Global 200',
#  'peak_position': '25',
#  'rank': '25',
#  'singer': 'The Neighbourhood',
#  'title': 'Sweater Weather',
#  'weaks_on_charts': '107'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/06/joji-77h-glimpse-of-us-gt3-180x180.jpg',
#  'last_position': '34',
#  'name': 'Billboard Hot 100',
#  'peak_position': '8',
#  'rank': '34',
#  'singer': 'Joji',
#  'title': 'Glimpse Of Us',
#  'weaks_on_charts': '18'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/jax-6vn-victoriassecret-745-180x180.jpg',
#  'last_position': '35',
#  'name': 'Billboard Hot 100',
#  'peak_position': '35',
#  'rank': '35',
#  'singer': 'Jax',
#  'title': 'Victoria’s Secret',
#  'weaks_on_charts': '11'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/09/elton-john-m6x-holdmecloser-cos-180x180.jpg',
#  'last_position': '26',
#  'name': 'Billboard Global 200',
#  'peak_position': '6',
#  'rank': '26',
#  'singer': 'Elton John & Britney Spears',
#  'title': 'Hold Me Closer',
#  'weaks_on_charts': '7'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/08/d4vd-7p1-romantichomicide-98c-180x180.jpg',
#  'last_position': '36',
#  'name': 'Billboard Hot 100',
#  'peak_position': '33',
#  'rank': '36',
#  'singer': 'd4vd',
#  'title': 'Romantic Homicide',
#  'weaks_on_charts': '6'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/07/the-kid-laroi-qev-stay-vsd-180x180.jpg',
#  'last_position': '27',
#  'name': 'Billboard Global 200',
#  'peak_position': '1',
#  'rank': '27',
#  'singer': 'The Kid LAROI & Justin Bieber',
#  'title': 'Stay',
#  'weaks_on_charts': '66'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2021/10/jelly-roll-54d-son-of-a-sinner-f0f-180x180.jpg',
#  'last_position': '37',
#  'name': 'Billboard Hot 100',
#  'peak_position': '31',
#  'rank': '37',
#  'singer': 'Jelly Roll',
#  'title': 'Son Of A Sinner',
#  'weaks_on_charts': '15'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/03/stephensanchez-s9k-untilifoundyou-6xd-180x180.jpg',
#  'last_position': '38',
#  'name': 'Billboard Hot 100',
#  'peak_position': '38',
#  'rank': '38',
#  'singer': 'Stephen Sanchez',
#  'title': 'Until I Found You',
#  'weaks_on_charts': '15'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/10/lil-nas-x-qv4-starwalkinleagueoflegendsworldsanthem-s28-180x180.jpg',
#  'last_position': '28',
#  'name': 'Billboard Global 200',
#  'peak_position': '21',
#  'rank': '28',
#  'singer': 'Lil Nas X',
#  'title': "Star Walkin' (League Of Legends Worlds Anthem)",
#  'weaks_on_charts': '3'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/04/nicky-youre-alv-sunroof-n0r-180x180.jpg',
#  'last_position': '29',
#  'name': 'Billboard Global 200',
#  'peak_position': '26',
#  'rank': '29',
#  'singer': 'Nicky Youre & dazy',
#  'title': 'Sunroof',
#  'weaks_on_charts': '21'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/yunggravy-oae-bettygetmoney-q8e-180x180.jpg',
#  'last_position': '39',
#  'name': 'Billboard Hot 100',
#  'peak_position': '30',
#  'rank': '39',
#  'singer': 'Yung Gravy',
#  'title': 'Betty (Get Money)',
#  'weaks_on_charts': '14'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/04/lilbaby-kyx-inaminute-7uc-180x180.jpg',
#  'last_position': '40',
#  'name': 'Billboard Hot 100',
#  'peak_position': '14',
#  'rank': '40',
#  'singer': 'Lil Baby',
#  'title': 'In A Minute',
#  'weaks_on_charts': '27'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/bad-bunny-c3m-180x180.jpg',
#  'last_position': '30',
#  'name': 'Billboard Global 200',
#  'peak_position': '16',
#  'rank': '30',
#  'singer': 'Bad Bunny',
#  'title': 'Neverita',
#  'weaks_on_charts': '23'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/06/jordan-davis-8bp-what-my-world-spins-around-3ix-180x180.jpg',
#  'last_position': '41',
#  'name': 'Billboard Hot 100',
#  'peak_position': '41',
#  'rank': '41',
#  'singer': 'Jordan Davis',
#  'title': 'What My World Spins Around',
#  'weaks_on_charts': '9'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/charlie-puth-9ci-leftandright-pbm-180x180.jpg',
#  'last_position': '42',
#  'name': 'Billboard Hot 100',
#  'peak_position': '22',
#  'rank': '42',
#  'singer': 'Charlie Puth Featuring Jung Kook',
#  'title': 'Left And Right',
#  'weaks_on_charts': '16'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/08/elton-john-m6x-cold-heart-pnau-remix-8pz-180x180.jpg',
#  'last_position': '31',
#  'name': 'Billboard Global 200',
#  'peak_position': '3',
#  'rank': '31',
#  'singer': 'Elton John & Dua Lipa',
#  'title': 'Cold Heart (PNAU Remix)',
#  'weaks_on_charts': '61'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/03/imagine-dragons-ud7-bones-8cg-180x180.jpg',
#  'last_position': '32',
#  'name': 'Billboard Global 200',
#  'peak_position': '32',
#  'rank': '32',
#  'singer': 'Imagine Dragons',
#  'title': 'Bones',
#  'weaks_on_charts': '31'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/bad-bunny-c3m-180x180.jpg',
#  'last_position': '43',
#  'name': 'Billboard Hot 100',
#  'peak_position': '4',
#  'rank': '43',
#  'singer': 'Bad Bunny',
#  'title': 'Moscow Mule',
#  'weaks_on_charts': '23'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/05/nate-smith-ry3-whiskey-on-you-9sh-180x180.jpg',
#  'last_position': '44',
#  'name': 'Billboard Hot 100',
#  'peak_position': '44',
#  'rank': '44',
#  'singer': 'Nate Smith',
#  'title': 'Whiskey On You',
#  'weaks_on_charts': '17'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/06/joji-77h-glimpse-of-us-xra-180x180.jpg',
#  'last_position': '33',
#  'name': 'Billboard Global 200',
#  'peak_position': '2',
#  'rank': '33',
#  'singer': 'Joji',
#  'title': 'Glimpse Of Us',
#  'weaks_on_charts': '18'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2021/03/kate-bush-qv2-running-up-that-hill-1cx-180x180.jpg',
#  'last_position': '45',
#  'name': 'Billboard Hot 100',
#  'peak_position': '3',
#  'rank': '45',
#  'singer': 'Kate Bush',
#  'title': 'Running Up That Hill (A Deal With God)',
#  'weaks_on_charts': '40'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2021/10/latto-80q-big-energy-89t-180x180.jpg',
#  'last_position': '46',
#  'name': 'Billboard Hot 100',
#  'peak_position': '3',
#  'rank': '46',
#  'singer': 'Latto',
#  'title': 'Big Energy',
#  'weaks_on_charts': '51'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/charlie-puth-9ci-leftandright-z0u-180x180.jpg',
#  'last_position': '34',
#  'name': 'Billboard Global 200',
#  'peak_position': '5',
#  'rank': '34',
#  'singer': 'Charlie Puth Featuring Jung Kook',
#  'title': 'Left And Right',
#  'weaks_on_charts': '16'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2021/08/ingridandress-eh5-wishfuldrinking-z8o-180x180.jpg',
#  'last_position': '47',
#  'name': 'Billboard Hot 100',
#  'peak_position': '47',
#  'rank': '47',
#  'singer': 'Ingrid Andress With Sam Hunt',
#  'title': 'Wishful Drinking',
#  'weaks_on_charts': '15'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/05/burna-boy-8ej-last-last-ld2-180x180.jpg',
#  'last_position': '48',
#  'name': 'Billboard Hot 100',
#  'peak_position': '44',
#  'rank': '48',
#  'singer': 'Burna Boy',
#  'title': 'Last Last',
#  'weaks_on_charts': '14'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/08/d4vd-7p1-180x180.jpg',
#  'last_position': '35',
#  'name': 'Billboard Global 200',
#  'peak_position': '35',
#  'rank': '35',
#  'singer': 'd4vd',
#  'title': 'Romantic Homicide',
#  'weaks_on_charts': '6'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/08/dj-khaled-2l5-stayingalive-2c6-180x180.jpg',
#  'last_position': '49',
#  'name': 'Billboard Hot 100',
#  'peak_position': '5',
#  'rank': '49',
#  'singer': 'DJ Khaled Featuring Drake & Lil Baby',
#  'title': 'Staying Alive',
#  'weaks_on_charts': '10'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2021/05/tems-67h-180x180.jpg',
#  'last_position': '50',
#  'name': 'Billboard Hot 100',
#  'peak_position': '46',
#  'rank': '50',
#  'singer': 'Tems',
#  'title': 'Free Mind',
#  'weaks_on_charts': '13'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/12/the-weeknd-xmx-dieforyou-yho-180x180.jpg',
#  'last_position': '36',
#  'name': 'Billboard Global 200',
#  'peak_position': '36',
#  'rank': '36',
#  'singer': 'The Weeknd',
#  'title': 'Die For You',
#  'weaks_on_charts': '32'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/05/hitkidd-000-fnf-lets-go-2k4-180x180.jpg',
#  'last_position': '51',
#  'name': 'Billboard Hot 100',
#  'peak_position': '42',
#  'rank': '51',
#  'singer': 'Hitkidd & GloRilla',
#  'title': "F.N.F. (Let's Go)",
#  'weaks_on_charts': '20'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/hot-100/>
# {'img': 'https://charts-static.billboard.com/img/2022/03/jacksondean-mx3-dontcomelookin-8er-180x180.jpg',
#  'last_position': '52',
#  'name': 'Billboard Hot 100',
#  'peak_position': '52',
#  'rank': '52',
#  'singer': 'Jackson Dean',
#  'title': "Don't Come Lookin'",
#  'weaks_on_charts': '7'}
# 2022-10-20 15:22:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2015/06/post-malone-8b5-180x180.jpg',
#  'last_position': '37',
#  'name': 'Billboard Global 200',
#  'peak_position': '7',
#  'rank': '37',
#  'singer': 'Post Malone Featuring Doja Cat',
# ...
# {'img': 'https://charts-static.billboard.com/img/2020/11/bad-bunny-c3m-dakiti-wxy-180x180.jpg',
#  'last_position': '164',
#  'name': 'Billboard Global 200',
#  'peak_position': '1',
#  'rank': '164',
#  'singer': 'Bad Bunny & Jhay Cortez',
#  'title': 'Dakiti',
#  'weaks_on_charts': '102'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2012/07/eminem-6zg-the-real-slim-shady-cbz-180x180.jpg',
#  'last_position': '165',
#  'name': 'Billboard Global 200',
#  'peak_position': '59',
#  'rank': '165',
#  'singer': 'Eminem',
#  'title': 'The Real Slim Shady',
#  'weaks_on_charts': '41'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/12/rauw-alejandro-rbn-desesperados-n5s-180x180.jpg',
#  'last_position': '166',
#  'name': 'Billboard Global 200',
#  'peak_position': '13',
#  'rank': '166',
#  'singer': 'Rauw Alejandro & Chencho Corleone',
#  'title': 'Desesperados',
#  'weaks_on_charts': '43'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/bad-bunny-c3m-180x180.jpg',
#  'last_position': '167',
#  'name': 'Billboard Global 200',
#  'peak_position': '7',
#  'rank': '167',
#  'singer': 'Bad Bunny',
#  'title': 'Despues de La Playa',
#  'weaks_on_charts': '23'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2018/04/doja-cat-lm6-180x180.jpg',
#  'last_position': '168',
#  'name': 'Billboard Global 200',
#  'peak_position': '11',
#  'rank': '168',
#  'singer': 'Doja Cat',
#  'title': 'Woman',
#  'weaks_on_charts': '65'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2015/11/dua-lipa-5k0-180x180.jpg',
#  'last_position': '169',
#  'name': 'Billboard Global 200',
#  'peak_position': '30',
#  'rank': '169',
#  'singer': 'Dua Lipa',
#  'title': "Don't Start Now",
#  'weaks_on_charts': '110'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2013/06/cole-swindell-2q7-180x180.jpg',
#  'last_position': '170',
#  'name': 'Billboard Global 200',
#  'peak_position': '81',
#  'rank': '170',
#  'singer': 'Cole Swindell',
#  'title': 'She Had Me At Heads Carolina',
#  'weaks_on_charts': '16'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2017/11/lilbaby-kyx-180x180.jpg',
#  'last_position': '171',
#  'name': 'Billboard Global 200',
#  'peak_position': '169',
#  'rank': '171',
#  'singer': 'Lil Baby',
#  'title': 'Freestyle',
#  'weaks_on_charts': '6'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2013/08/vance-joy-578-180x180.jpg',
#  'last_position': '172',
#  'name': 'Billboard Global 200',
#  'peak_position': '130',
#  'rank': '172',
#  'singer': 'Vance Joy',
#  'title': 'Riptide',
#  'weaks_on_charts': '65'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/public/lazyload-fallback.gif',
#  'last_position': '173',
#  'name': 'Billboard Global 200',
#  'peak_position': '173',
#  'rank': '173',
#  'singer': 'natori',
#  'title': 'Overdose',
#  'weaks_on_charts': '1'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2005/08/journey-0b3-dontstopbelievin-mvt-180x180.jpg',
#  'last_position': '174',
#  'name': 'Billboard Global 200',
#  'peak_position': '125',
#  'rank': '174',
#  'singer': 'Journey',
#  'title': "Don't Stop Believin'",
#  'weaks_on_charts': '91'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/the-black-eyed-peas-f5s-dont-you-worry-sb1-180x180.jpg',
#  'last_position': '175',
#  'name': 'Billboard Global 200',
#  'peak_position': '103',
#  'rank': '175',
#  'singer': 'Black Eyed Peas, Shakira + David Guetta',
#  'title': "Don't You Worry",
#  'weaks_on_charts': '10'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2012/12/bruno-mars-va7-180x180.jpg',
#  'last_position': '176',
#  'name': 'Billboard Global 200',
#  'peak_position': '157',
#  'rank': '176',
#  'singer': 'Bruno Mars',
#  'title': 'When I Was Your Man',
#  'weaks_on_charts': '7'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2006/07/taylor-swift-5wo-180x180.jpg',
#  'last_position': '177',
#  'name': 'Billboard Global 200',
#  'peak_position': '157',
#  'rank': '177',
#  'singer': 'Taylor Swift',
#  'title': 'Blank Space',
#  'weaks_on_charts': '18'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/feid-ug7-normal-pn7-180x180.jpg',
#  'last_position': '178',
#  'name': 'Billboard Global 200',
#  'peak_position': '75',
#  'rank': '178',
#  'singer': 'Feid',
#  'title': 'Normal',
#  'weaks_on_charts': '13'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2017/07/cigarettes-after-sex-0oe-180x180.jpg',
#  'last_position': '179',
#  'name': 'Billboard Global 200',
#  'peak_position': '174',
#  'rank': '179',
#  'singer': 'Cigarettes After Sex',
#  'title': 'Apocalypse',
#  'weaks_on_charts': '3'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2011/05/fleetwood-mac-fe3-dreams-jvb-180x180.jpg',
#  'last_position': '180',
#  'name': 'Billboard Global 200',
#  'peak_position': '10',
#  'rank': '180',
#  'singer': 'Fleetwood Mac',
#  'title': 'Dreams',
#  'weaks_on_charts': '105'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2004/12/the-killers-7vb-mrbrightside-7k3-180x180.jpg',
#  'last_position': '181',
#  'name': 'Billboard Global 200',
#  'peak_position': '115',
#  'rank': '181',
#  'singer': 'The Killers',
#  'title': 'Mr. Brightside',
#  'weaks_on_charts': '68'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/1971/10/michael-jackson-9to-180x180.jpg',
#  'last_position': '182',
#  'name': 'Billboard Global 200',
#  'peak_position': '137',
#  'rank': '182',
#  'singer': 'Michael Jackson',
#  'title': 'Billie Jean',
#  'weaks_on_charts': '33'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/12/steve-lacy-d2o-180x180.jpg',
#  'last_position': '183',
#  'name': 'Billboard Global 200',
#  'peak_position': '159',
#  'rank': '183',
#  'singer': 'Steve Lacy',
#  'title': 'Static',
#  'weaks_on_charts': '5'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2019/04/billie-eilish-lrt-bad-guy-vul-180x180.jpg',
#  'last_position': '184',
#  'name': 'Billboard Global 200',
#  'peak_position': '54',
#  'rank': '184',
#  'singer': 'Billie Eilish',
#  'title': 'Bad Guy',
#  'weaks_on_charts': '107'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/10/wisin-yandel-cfr-besosmoja2-9u8-180x180.jpg',
#  'last_position': '185',
#  'name': 'Billboard Global 200',
#  'peak_position': '178',
#  'rank': '185',
#  'singer': 'Wisin & Yandel + Rosalia',
#  'title': 'Besos Moja2',
#  'weaks_on_charts': '2'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2005/02/keane-flj-106x106.jpg',
#  'last_position': '186',
#  'name': 'Billboard Global 200',
#  'peak_position': '186',
#  'rank': '186',
#  'singer': 'Keane',
#  'title': 'Somewhere Only We Know',
#  'weaks_on_charts': '2'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/1972/06/eagles-ma9-180x180.jpg',
#  'last_position': '187',
#  'name': 'Billboard Global 200',
#  'peak_position': '132',
#  'rank': '187',
#  'singer': 'Eagles',
#  'title': 'Hotel California',
#  'weaks_on_charts': '94'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2019/06/girl-in-red-j8w-180x180.jpg',
#  'last_position': '188',
#  'name': 'Billboard Global 200',
#  'peak_position': '154',
#  'rank': '188',
#  'singer': 'girl in red',
#  'title': 'We Fell In Love In October',
#  'weaks_on_charts': '2'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/06/bad-bunny-c3m-yonaguni-zqi-180x180.jpg',
#  'last_position': '189',
#  'name': 'Billboard Global 200',
#  'peak_position': '3',
#  'rank': '189',
#  'singer': 'Bad Bunny',
#  'title': 'Yonaguni',
#  'weaks_on_charts': '71'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2012/12/ac-dc-3eb-180x180.jpg',
#  'last_position': '190',
#  'name': 'Billboard Global 200',
#  'peak_position': '162',
#  'rank': '190',
#  'singer': 'AC/DC',
#  'title': 'Thunderstruck',
#  'weaks_on_charts': '69'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/01/olivia-rodrigo-3wl-drivers-license-w08-180x180.jpg',
#  'last_position': '191',
#  'name': 'Billboard Global 200',
#  'peak_position': '1',
#  'rank': '191',
#  'singer': 'Olivia Rodrigo',
#  'title': 'Drivers License',
#  'weaks_on_charts': '92'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/10/coldplay-bm3-my-universe-68v-180x180.jpg',
#  'last_position': '192',
#  'name': 'Billboard Global 200',
#  'peak_position': '1',
#  'rank': '192',
#  'singer': 'Coldplay x BTS',
#  'title': 'My Universe',
#  'weaks_on_charts': '55'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2014/05/ajr-yr7-180x180.jpg',
#  'last_position': '193',
#  'name': 'Billboard Global 200',
#  'peak_position': '189',
#  'rank': '193',
#  'singer': 'AJR',
#  'title': "World's Smallest Violin",
#  'weaks_on_charts': '6'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/1840/12/imagine-dragons-hy6-180x180.jpg',
#  'last_position': '194',
#  'name': 'Billboard Global 200',
#  'peak_position': '167',
#  'rank': '194',
#  'singer': 'Imagine Dragons',
#  'title': 'Thunder',
#  'weaks_on_charts': '42'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/09/mrkitty-1g9-180x180.jpg',
#  'last_position': '195',
#  'name': 'Billboard Global 200',
#  'peak_position': '195',
#  'rank': '195',
#  'singer': 'Mr.Kitty',
#  'title': 'After Dark',
#  'weaks_on_charts': '1'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/03/silk-sonic-bruno-mars-and-anderson-paak-qd5-leave-the-door-open-ife-180x180.jpg',
#  'last_position': '196',
#  'name': 'Billboard Global 200',
#  'peak_position': '2',
#  'rank': '196',
#  'singer': 'Silk Sonic (Bruno Mars & Anderson .Paak)',
#  'title': 'Leave The Door Open',
#  'weaks_on_charts': '71'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/05/imanbek-000-belly-dancer-voa-180x180.jpg',
#  'last_position': '197',
#  'name': 'Billboard Global 200',
#  'peak_position': '132',
#  'rank': '197',
#  'singer': 'Imanbek & BYOR',
#  'title': 'Belly Dancer',
#  'weaks_on_charts': '16'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2011/07/ed-sheeran-w3r-180x180.jpg',
#  'last_position': '198',
#  'name': 'Billboard Global 200',
#  'peak_position': '103',
#  'rank': '198',
#  'singer': 'Ed Sheeran',
#  'title': 'Thinking Out Loud',
#  'weaks_on_charts': '73'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/yunggravy-oae-bettygetmoney-e19-180x180.jpg',
#  'last_position': '199',
#  'name': 'Billboard Global 200',
#  'peak_position': '81',
#  'rank': '199',
#  'singer': 'Yung Gravy',
#  'title': 'Betty (Get Money)',
#  'weaks_on_charts': '14'}
# 2022-10-20 15:22:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2013/02/macklemore-ryan-lewis-th1-180x180.jpg',
#  'last_position': '200',
#  'name': 'Billboard Global 200',
#  'peak_position': '148',
#  'rank': '200',
#  'singer': 'Macklemore & Ryan Lewis Featuring Ray Dalton',
#  'title': "Can't Hold Us",
#  'weaks_on_charts': '10'}
# 2022-10-20 15:22:23 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-10-20 15:22:23 [scrapy.extensions.feedexport] INFO: Stored csv feed (325 items) in: billboard.csv
# 2022-10-20 15:22:23 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 942,
#  'downloader/request_count': 4,
#  'downloader/request_method_count/GET': 4,
#  'downloader/response_bytes': 496994,
#  'downloader/response_count': 4,
#  'downloader/response_status_count/200': 4,
#  'elapsed_time_seconds': 2.925753,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 10, 20, 13, 22, 23, 393623),
#  'httpcompression/response_bytes': 6970656,
#  'httpcompression/response_count': 4,
#  'item_scraped_count': 325,
#  'log_count/DEBUG': 332,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 1,
#  'memusage/max': 95657984,
#  'memusage/startup': 95657984,
#  'response_received_count': 4,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 3,
#  'scheduler/dequeued/memory': 3,
#  'scheduler/enqueued': 3,
#  'scheduler/enqueued/memory': 3,
#  'start_time': datetime.datetime(2022, 10, 20, 13, 22, 20, 467870)}
# 2022-10-20 15:22:23 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
import pandas as pd

df = pd.read_csv('./BillBoard/spiders/billboard.csv')
df
# Out:
#                                                    img  last_position  \
# 0    https://charts-static.billboard.com/img/2022/1...              1
# 1    https://charts-static.billboard.com/img/2022/0...              2
# 2    https://charts-static.billboard.com/img/2022/0...              3
# 3    https://charts-static.billboard.com/img/2005/0...              4
# 4    https://charts-static.billboard.com/img/2022/0...              5
# ..                                                 ...            ...
# 320  https://charts-static.billboard.com/img/2021/0...            196
# 321  https://charts-static.billboard.com/img/2022/0...            197
# 322  https://charts-static.billboard.com/img/2011/0...            198
# 323  https://charts-static.billboard.com/img/2022/0...            199
# 324  https://charts-static.billboard.com/img/2013/0...            200
#
#                      name  peak_position  rank  \
# 0    Billboard Global 200              1     1
# 1    Billboard Global 200              2     2
# 2    Billboard Global 200              1     3
# 3    Billboard Global 200              4     4
# 4    Billboard Global 200              5     5
# ..                    ...            ...   ...
# 320  Billboard Global 200              2   196
# 321  Billboard Global 200            132   197
# 322  Billboard Global 200            103   198
# 323  Billboard Global 200             81   199
# 324  Billboard Global 200            148   200
#
#                                            singer                title  \
# 0                          Sam Smith & Kim Petras               Unholy
# 1                       David Guetta & Bebe Rexha      I'm Good (Blue)
# 2                                    Harry Styles            As It Was
# 3                                     Chris Brown  Under The Influence
# 4                                     OneRepublic      I Ain't Worried
# ..                                            ...                  ...
# 320      Silk Sonic (Bruno Mars & Anderson .Paak)  Leave The Door Open
# 321                                Imanbek & BYOR         Belly Dancer
# 322                                    Ed Sheeran    Thinking Out Loud
# 323                                    Yung Gravy    Betty (Get Money)
# 324  Macklemore & Ryan Lewis Featuring Ray Dalton        Can't Hold Us
#
#      weaks_on_charts
# 0                  1
# 1                  7
# 2                 28
# 3                 12
# 4                 19
# ..               ...
# 320               71
# 321               16
# 322               73
# 323               14
# 324               10
#
# [325 rows x 8 columns]
