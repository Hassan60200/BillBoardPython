# %%
class BillboardItem(scrapy.Item):
    # define the fields for your item here like:
        rank = scrapy.Field()
        img = scrapy.Field()
        title = scrapy.Field()
        singer = scrapy.Field()
        last_position = scrapy.Field()
        peak_position = scrapy.Field()
        weaks_on_charts = scrapy.Field()

# %%
import scrapy
from scrapy import Request
from BillBoard.items import BillboardItem

class BillboardSpider(scrapy.Spider):
    name = 'billBoard'
    allowed_domains = ['www.billboard.com']
    start_urls = ['https://www.billboard.com/charts/billboard-global-200/']

    def start_requests(self):
        for url in self.start_urls:
            yield Request(url=url, callback=self.parse_song)

    def parse_song(self, response):
        liste_song = response.css('.o-chart-results-list-row-container')
        
        for song in liste_song:
            item = BillboardItem()
            
            # Rank de la musique
            try:
                item['rank'] = song.css('li.o-chart-results-list__item span::text')[0].extract().strip()
            except:
                item['rank'] = 'None'
                
            # img de la musique
            try:
                item['img'] = song.css('li.o-chart-results-list__item img.c-lazy-image__img.lrv-u-background-color-grey-lightest.lrv-u-width-100p.lrv-u-display-block.lrv-u-height-auto').attrib['data-lazy-src']
            except:
                item['img'] = 'None'
            
            # title de la musique
            try:
                item['title'] = song.css('li.o-chart-results-list__item h3::text')[0].extract().strip()
            except:
                item['title'] = 'None'
        
            # singer de la musique
            try:
                item['singer'] = song.css('li.lrv-u-width-100p span.c-label::text').get().strip()
            except:
                item['singer'] = 'None'
            
               # Dernière position au classement de la musique
            try:
                item['last_position'] = song.css('li.o-chart-results-list__item .c-label.a-font-primary-bold-l::text')[0].extract().strip()
            except:
                item['last_position'] = song.css('li.o-chart-results-list__item .c-label.a-font-primary-m::text')[0].extract().strip()
               
            # Meilleur position au classement de la musique
            try:
                item['peak_position'] = song.css('li.o-chart-results-list__item .c-label.a-font-primary-bold-l::text')[1].extract().strip()
            except:
                item['peak_position'] = song.css('li.o-chart-results-list__item .c-label.a-font-primary-m::text')[1].extract().strip()
                
            # Durée dans le classement
            try:
                item['weaks_on_charts'] = song.css('li.o-chart-results-list__item .c-label.a-font-primary-bold-l::text')[2].extract().strip()
            except:
                item['weaks_on_charts'] = song.css('li.o-chart-results-list__item .c-label.a-font-primary-m::text')[2].extract().strip()
        
            yield item

# %%
# !cd BillBoard/spiders && scrapy crawl billBoard -o billboard.csv
# Out:
# 2022-10-20 14:23:20 [scrapy.utils.log] INFO: Scrapy 2.7.0 started (bot: BillBoard)
# 2022-10-20 14:23:20 [scrapy.utils.log] INFO: Versions: lxml 4.8.0.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.8.0, Python 3.10.4 (main, Jun 29 2022, 12:14:53) [GCC 11.2.0], pyOpenSSL 22.1.0 (OpenSSL 3.0.5 5 Jul 2022), cryptography 38.0.1, Platform Linux-5.15.0-50-generic-x86_64-with-glibc2.35
# 2022-10-20 14:23:20 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'BillBoard',
#  'NEWSPIDER_MODULE': 'BillBoard.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['BillBoard.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2022-10-20 14:23:20 [asyncio] DEBUG: Using selector: EpollSelector
# 2022-10-20 14:23:20 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2022-10-20 14:23:20 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2022-10-20 14:23:20 [scrapy.extensions.telnet] INFO: Telnet Password: 41e2017dba585c76
# 2022-10-20 14:23:20 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 
}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '168', 'peak_position': '11', 'weaks_on_charts': '65'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '169', 'peak_position': '30', 'weaks_on_charts': '110'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '170', 'peak_position': '81', 'weaks_on_charts': '16'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '171', 'peak_position': '169', 'weaks_on_charts': '6'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '172', 'peak_position': '130', 'weaks_on_charts': '65'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '173', 'peak_position': '173', 'weaks_on_charts': '1'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '174', 'peak_position': '125', 'weaks_on_charts': '91'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '175', 'peak_position': '103', 'weaks_on_charts': '10'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '176', 'peak_position': '157', 'weaks_on_charts': '7'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '177', 'peak_position': '157', 'weaks_on_charts': '18'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '178', 'peak_position': '75', 'weaks_on_charts': '13'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '179', 'peak_position': '174', 'weaks_on_charts': '3'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '180', 'peak_position': '10', 'weaks_on_charts': '105'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '181', 'peak_position': '115', 'weaks_on_charts': '68'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '182', 'peak_position': '137', 'weaks_on_charts': '33'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '183', 'peak_position': '159', 'weaks_on_charts': '5'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '184', 'peak_position': '54', 'weaks_on_charts': '107'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '185', 'peak_position': '178', 'weaks_on_charts': '2'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '186', 'peak_position': '186', 'weaks_on_charts': '2'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '187', 'peak_position': '132', 'weaks_on_charts': '94'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '188', 'peak_position': '154', 'weaks_on_charts': '2'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '189', 'peak_position': '3', 'weaks_on_charts': '71'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '190', 'peak_position': '162', 'weaks_on_charts': '69'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '191', 'peak_position': '1', 'weaks_on_charts': '92'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '192', 'peak_position': '1', 'weaks_on_charts': '55'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '193', 'peak_position': '189', 'weaks_on_charts': '6'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '194', 'peak_position': '167', 'weaks_on_charts': '42'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '195', 'peak_position': '195', 'weaks_on_charts': '1'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '196', 'peak_position': '2', 'weaks_on_charts': '71'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '197', 'peak_position': '132', 'weaks_on_charts': '16'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '198', 'peak_position': '103', 'weaks_on_charts': '73'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '199', 'peak_position': '81', 'weaks_on_charts': '14'}
# 2022-10-20 14:23:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'last_position': '200', 'peak_position': '148', 'weaks_on_charts': '10'}
# 2022-10-20 14:23:20 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-10-20 14:23:20 [scrapy.extensions.feedexport] INFO: Stored csv feed (200 items) in: billboard.csv
# 2022-10-20 14:23:20 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 480,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 198397,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'elapsed_time_seconds': 0.625965,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 10, 20, 12, 23, 20, 799872),
#  'httpcompression/response_bytes': 3599465,
#  'httpcompression/response_count': 2,
#  'item_scraped_count': 200,
#  'log_count/DEBUG': 205,
#  'log_count/INFO': 11,
#  'memusage/max': 109961216,
#  'memusage/startup': 109961216,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2022, 10, 20, 12, 23, 20, 173907)}
# 2022-10-20 14:23:20 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
import pandas as pd

df = pd.read_csv('./BillBoard/spiders/billboard.csv')
df
# Out:
#      img  last_position  peak_position  rank  singer  title  weaks_on_charts
# 0    NaN              1              1   NaN     NaN    NaN                1
# 1    NaN              2              2   NaN     NaN    NaN                7
# 2    NaN              3              1   NaN     NaN    NaN               28
# 3    NaN              4              4   NaN     NaN    NaN               12
# 4    NaN              5              5   NaN     NaN    NaN               19
# ..   ...            ...            ...   ...     ...    ...              ...
# 195  NaN            196              2   NaN     NaN    NaN               71
# 196  NaN            197            132   NaN     NaN    NaN               16
# 197  NaN            198            103   NaN     NaN    NaN               73
# 198  NaN            199             81   NaN     NaN    NaN               14
# 199  NaN            200            148   NaN     NaN    NaN               10
#
# [200 rows x 7 columns]
