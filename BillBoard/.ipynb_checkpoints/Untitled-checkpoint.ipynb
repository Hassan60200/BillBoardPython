# %%
class BillboardItem(scrapy.Item):
    # define the fields for your item here like:
        rank = scrapy.Field()
        img = scrapy.Field()
        title = scrapy.Field()
        singer = scrapy.Field()
        last_position = scrapy.Field()
        peak_position = scrapy.Field()
        weaks_on_charts = scrapy.Field()

# %%
# Rank de la musique
response.css('.o-chart-results-list-row-container')[0].css('li.o-chart-results-list__item span::text')[0].extract()
# img de la musique
response.css('.o-chart-results-list-row-container')[0].css('li.o-chart-results-list__item img.c-lazy-image__img.lrv-u-background-color-grey-lightest.lrv-u-width-100p.lrv-u-display-block.lrv-u-height-auto').attrib['data-lazy-src']
# title de la musique
response.css('.o-chart-results-list-row-container')[0].css('li.o-chart-results-list__item h3::text')[0].extract().strip()
# singer de la musique
response.css('.o-chart-results-list-row-container')[0].css('li.lrv-u-width-100p span.c-label::text').get().strip()

# %%
import scrapy
from scrapy import Request
from BillBoard.items import BillboardItem

class BillboardSpider(scrapy.Spider):
    name = 'billBoard'
    allowed_domains = ['www.billboard.com']
    start_urls = ['https://www.billboard.com/charts/billboard-global-200/']

    def start_requests(self):
        for url in self.start_urls:
            yield Request(url=url, callback=self.parse_song)

    def parse_song(self, response):
        liste_song = response.css('.o-chart-results-list-row-container')
        
        for song in liste_song:
            item = BillboardItem()
            
            # Rank de la musique
            try:
                item['rank'] = song.css('li.o-chart-results-list__item span::text')[0].extract().strip()
            except:
                item['rank'] = 'None'
                
            # img de la musique
            try:
                item['img'] = song.css('li.o-chart-results-list__item img.c-lazy-image__img.lrv-u-background-color-grey-lightest.lrv-u-width-100p.lrv-u-display-block.lrv-u-height-auto').attrib['data-lazy-src']
            except:
                item['img'] = 'None'
            
            # title de la musique
            try:
                item['title'] = song.css('li.o-chart-results-list__item h3::text')[0].extract().strip()
            except:
                item['title'] = 'None'
        
            # singer de la musique
            try:
                item['singer'] = song.css('li.lrv-u-width-100p span.c-label::text').get().strip()
            except:
                item['singer'] = 'None'
            
               # Dernière position au classement de la musique
            try:
                item['last_position'] = song.css('li.o-chart-results-list__item .c-label.a-font-primary-bold-l::text')[0].extract().strip()
            except:
                item['last_position'] = song.css('li.o-chart-results-list__item .c-label.a-font-primary-m::text')[0].extract().strip()
               
            # Meilleur position au classement de la musique
            try:
                item['peak_position'] = song.css('li.o-chart-results-list__item .c-label.a-font-primary-bold-l::text')[1].extract().strip()
            except:
                item['peak_position'] = song.css('li.o-chart-results-list__item .c-label.a-font-primary-m::text')[1].extract().strip()
                
            # Durée dans le classement
            try:
                item['weaks_on_charts'] = song.css('li.o-chart-results-list__item .c-label.a-font-primary-bold-l::text')[2].extract().strip()
            except:
                item['weaks_on_charts'] = song.css('li.o-chart-results-list__item .c-label.a-font-primary-m::text')[2].extract().strip()
        
            yield item

# %%
# !cd BillBoard/spiders && scrapy crawl billBoard -o billboard.csv
# Out:
# 2022-10-20 14:10:51 [scrapy.utils.log] INFO: Scrapy 2.7.0 started (bot: BillBoard)
# 2022-10-20 14:10:51 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.8.0, Python 3.8.10 (default, Jun 22 2022, 20:18:18) - [GCC 9.4.0], pyOpenSSL 22.1.0 (OpenSSL 3.0.5 5 Jul 2022), cryptography 38.0.1, Platform Linux-5.15.0-50-generic-x86_64-with-glibc2.29
# 2022-10-20 14:10:51 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'BillBoard',
#  'NEWSPIDER_MODULE': 'BillBoard.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['BillBoard.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2022-10-20 14:10:51 [asyncio] DEBUG: Using selector: EpollSelector
# 2022-10-20 14:10:51 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2022-10-20 14:10:51 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2022-10-20 14:10:51 [scrapy.extensions.telnet] INFO: Telnet Password: 05f2e5f1e167242b
# 2022-10-20 14:10:51 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2022-10-20 14:10:51 [py.warnings] WARNING: /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
#
# 2022-10-20 14:10:51 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-10-20 14:10:51 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-10-20 14:10:51 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-10-20 14:10:51 [scrapy.core.engine] INFO: Spider opened
# 2022-10-20 14:10:51 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-10-20 14:10:51 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2022-10-20 14:10:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.billboard.com/robots.txt> (referer: None)
# 2022-10-20 14:10:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.billboard.com/charts/billboard-global-200/> (referer: None)
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/10/sam-smith-0od-unholy-dry-180x180.jpg',
#  'rank': '1',
#  'singer': 'Sam Smith & Kim Petras',
#  'title': 'Unholy'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/09/david-guetta-ruw-imgoodblue-rkt-180x180.jpg',
#  'rank': '2',
#  'singer': 'David Guetta & Bebe Rexha',
#  'title': "I'm Good (Blue)"}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/04/harry-styles-6jk-asitwas-frn-180x180.jpg',
#  'rank': '3',
#  'singer': 'Harry Styles',
#  'title': 'As It Was'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2005/07/chris-brown-94g-180x180.jpg',
#  'rank': '4',
#  'singer': 'Chris Brown',
#  'title': 'Under The Influence'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/06/onerepublic-m2z-i-aint-worried-6ds-180x180.jpg',
#  'rank': '5',
#  'singer': 'OneRepublic',
#  'title': "I Ain't Worried"}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/06/manuel-turizo-eml-la-bachata-1l6-180x180.jpg',
#  'rank': '6',
#  'singer': 'Manuel Turizo',
#  'title': 'La Bachata'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/bad-bunny-c3m-180x180.jpg',
#  'rank': '7',
#  'singer': 'Bad Bunny & Chencho Corleone',
#  'title': 'Me Porto Bonito'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/bad-bunny-c3m-180x180.jpg',
#  'rank': '8',
#  'singer': 'Bad Bunny',
#  'title': 'Titi Me Pregunto'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/bizarrap-rsm-bzrp-music-sessions-vol-52-6r7-180x180.jpg',
#  'rank': '9',
#  'singer': 'Bizarrap & Quevedo',
#  'title': 'Bzrp Music Sessions, Vol. 52'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/steve-lacy-d2o-badhabit-9nj-180x180.jpg',
#  'rank': '10',
#  'singer': 'Steve Lacy',
#  'title': 'Bad Habit'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/04/rema-000-calmdown-55o-180x180.jpg',
#  'rank': '11',
#  'singer': 'Rema & Selena Gomez',
#  'title': 'Calm Down'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2002/06/beyonce-0na-180x180.jpg',
#  'rank': '12',
#  'singer': 'Beyonce',
#  'title': 'Cuff It'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/08/blackpink-l5z-180x180.jpg',
#  'rank': '13',
#  'singer': 'BLACKPINK',
#  'title': 'Shut Down'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/08/nicki-minaj-721-superfreakygirl-y5e-180x180.jpg',
#  'rank': '14',
#  'singer': 'Nicki Minaj',
#  'title': 'Super Freaky Girl'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/08/rosalia-88x-despecha-hsd-180x180.jpg',
#  'rank': '15',
#  'singer': 'Rosalia',
#  'title': 'Despecha'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2013/01/tom-odell-qwt-180x180.jpg',
#  'rank': '16',
#  'singer': 'Tom Odell',
#  'title': 'Another Love'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/bad-bunny-c3m-180x180.jpg',
#  'rank': '17',
#  'singer': 'Bad Bunny',
#  'title': 'Efecto'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/09/blackpink-l5z-pinkvenom-t5p-180x180.jpg',
#  'rank': '18',
#  'singer': 'BLACKPINK',
#  'title': 'Pink Venom'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2020/07/glass-animals-rtd-heat-waves-1lv-180x180.jpg',
#  'rank': '19',
#  'singer': 'Glass Animals',
#  'title': 'Heat Waves'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/rosalinn-rc0-snap-c77-180x180.jpg',
#  'rank': '20',
#  'singer': 'Rosa Linn',
#  'title': 'Snap'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/bad-bunny-c3m-180x180.jpg',
#  'rank': '21',
#  'singer': 'Bad Bunny & Bomba Estereo',
#  'title': 'Ojitos Lindos'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2020/12/the-weeknd-xmx-save-your-tears-e5b-180x180.jpg',
#  'rank': '22',
#  'singer': 'The Weeknd & Ariana Grande',
#  'title': 'Save Your Tears'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/05/zach-bryan-cfd-something-in-the-orange-8ma-180x180.jpg',
#  'rank': '23',
#  'singer': 'Zach Bryan',
#  'title': 'Something In The Orange'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/bad-bunny-c3m-180x180.jpg',
#  'rank': '24',
#  'singer': 'Bad Bunny',
#  'title': 'Moscow Mule'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2013/03/the-neighbourhood-ro9-180x180.jpg',
#  'rank': '25',
#  'singer': 'The Neighbourhood',
#  'title': 'Sweater Weather'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/09/elton-john-m6x-holdmecloser-cos-180x180.jpg',
#  'rank': '26',
#  'singer': 'Elton John & Britney Spears',
#  'title': 'Hold Me Closer'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/07/the-kid-laroi-qev-stay-vsd-180x180.jpg',
#  'rank': '27',
#  'singer': 'The Kid LAROI & Justin Bieber',
#  'title': 'Stay'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/10/lil-nas-x-qv4-starwalkinleagueoflegendsworldsanthem-s28-180x180.jpg',
#  'rank': '28',
#  'singer': 'Lil Nas X',
#  'title': "Star Walkin' (League Of Legends Worlds Anthem)"}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/04/nicky-youre-alv-sunroof-n0r-180x180.jpg',
#  'rank': '29',
#  'singer': 'Nicky Youre & dazy',
#  'title': 'Sunroof'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/bad-bunny-c3m-180x180.jpg',
#  'rank': '30',
#  'singer': 'Bad Bunny',
#  'title': 'Neverita'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/08/elton-john-m6x-cold-heart-pnau-remix-8pz-180x180.jpg',
#  'rank': '31',
#  'singer': 'Elton John & Dua Lipa',
#  'title': 'Cold Heart (PNAU Remix)'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/03/imagine-dragons-ud7-bones-8cg-180x180.jpg',
#  'rank': '32',
#  'singer': 'Imagine Dragons',
#  'title': 'Bones'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/06/joji-77h-glimpse-of-us-xra-180x180.jpg',
#  'rank': '33',
#  'singer': 'Joji',
#  'title': 'Glimpse Of Us'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/charlie-puth-9ci-leftandright-z0u-180x180.jpg',
#  'rank': '34',
#  'singer': 'Charlie Puth Featuring Jung Kook',
#  'title': 'Left And Right'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/08/d4vd-7p1-180x180.jpg',
#  'rank': '35',
#  'singer': 'd4vd',
#  'title': 'Romantic Homicide'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/12/the-weeknd-xmx-dieforyou-yho-180x180.jpg',
#  'rank': '36',
#  'singer': 'The Weeknd',
#  'title': 'Die For You'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2015/06/post-malone-8b5-180x180.jpg',
#  'rank': '37',
#  'singer': 'Post Malone Featuring Doja Cat',
#  'title': 'I Like You (A Happier Song)'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2019/12/the-weeknd-xmx-blinding-lights-q48-180x180.jpg',
#  'rank': '38',
#  'singer': 'The Weeknd',
#  'title': 'Blinding Lights'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/09/grupofrontera-000-noseva-92t-180x180.jpg',
#  'rank': '39',
#  'singer': 'Grupo Frontera',
#  'title': 'No Se Va'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/04/karol-g-tb3-provenza-wah-180x180.jpg',
#  'rank': '40',
#  'singer': 'Karol G',
#  'title': 'Provenza'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2020/04/dua-lipa-eqf-levitating-tr9-180x180.jpg',
#  'rank': '41',
#  'singer': 'Dua Lipa',
#  'title': 'Levitating'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/06/kate-bush-qv2-running-up-that-hill-a-deal-with-god-cfi-180x180.jpg',
#  'rank': '42',
#  'singer': 'Kate Bush',
#  'title': 'Running Up That Hill (A Deal With God)'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/09/ed-sheeran-w3r-shivers-9kr-180x180.jpg',
#  'rank': '43',
#  'singer': 'Ed Sheeran',
#  'title': 'Shivers'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/04/lizzo-o9x-about-damn-time-k73-180x180.jpg',
#  'rank': '44',
#  'singer': 'Lizzo',
#  'title': 'About Damn Time'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2009/04/drake-04g-180x180.jpg',
#  'rank': '45',
#  'singer': 'Drake Featuring 21 Savage',
#  'title': 'Jimmy Cooks'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/06/harry-styles-6jk-latenighttalking-nw1-180x180.jpg',
#  'rank': '46',
#  'singer': 'Harry Styles',
#  'title': 'Late Night Talking'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/05/stephensanchez-s9k-untilifoundyou-n64-180x180.jpg',
#  'rank': '47',
#  'singer': 'Stephen Sanchez',
#  'title': 'Until I Found You'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2010/11/coolio-i15-gangstasparadise-nqq-180x180.jpg',
#  'rank': '48',
#  'singer': 'Coolio Featuring L.V.',
#  'title': "Gangsta's Paradise"}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/1988/03/future-f8b-180x180.jpg',
#  'rank': '49',
#  'singer': 'Future Featuring Drake & Tems',
#  'title': 'Wait For U'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/07/ed-sheeran-w3r-bad-habits-i7l-180x180.jpg',
#  'rank': '50',
#  'singer': 'Ed Sheeran',
#  'title': 'Bad Habits'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/08/elizarose-000-botabaddestofthemall-ahs-180x180.jpg',
#  'rank': '51',
#  'singer': 'Eliza Rose & Interplanetary Criminal',
#  'title': 'B.O.T.A. (Baddest Of Them All)'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/04/james-hype-000-ferrari-vua-180x180.jpg',
#  'rank': '52',
#  'singer': 'James Hype & Miggy Dela Rosa',
#  'title': 'Ferrari'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/09/karol-g-tb3-gatubela-p1y-180x180.jpg',
#  'rank': '53',
#  'singer': 'Karol G x Maldy',
#  'title': 'Gatubela'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2011/07/ed-sheeran-w3r-180x180.jpg',
#  'rank': '54',
#  'singer': 'Ed Sheeran',
#  'title': 'Perfect'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/08/rauw-alejandro-rbn-lokera-3xf-180x180.jpg',
#  'rank': '55',
#  'singer': 'Rauw Alejandro, Lyanno & Brray',
#  'title': 'Lokera'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/10/glorilla-000-tomorrow2-4zo-180x180.jpg',
#  'rank': '56',
#  'singer': 'GloRilla & Cardi B',
#  'title': 'Tomorrow 2'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/01/central-cee-v14-180x180.jpg',
#  'rank': '57',
#  'singer': 'Central Cee',
#  'title': 'Doja'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/10/ed-sheeran-w3r-celestial-z4e-180x180.jpg',
#  'rank': '58',
#  'singer': 'Ed Sheeran',
#  'title': 'Celestial'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2017/11/straykids-0y0-180x180.jpg',
#  'rank': '59',
#  'singer': 'Stray Kids',
#  'title': 'Case 143'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/11/imagine-dragons-ud7-enemy-hcl-180x180.jpg',
#  'rank': '60',
#  'singer': 'Imagine Dragons X JID',
#  'title': 'Enemy'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/feid-ug7-180x180.jpg',
#  'rank': '61',
#  'singer': 'Feid',
#  'title': 'Feliz Cumpleanos Ferxxo'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/05/doja-cat-lm6-vegas-gwm-180x180.jpg',
#  'rank': '62',
#  'singer': 'Doja Cat',
#  'title': 'Vegas'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/luke-combs-9dm-the-kind-of-love-we-make-hod-180x180.jpg',
#  'rank': '63',
#  'singer': 'Luke Combs',
#  'title': 'The Kind Of Love We Make'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/10/kenshi-yonezu-000-kickback-867-180x180.jpg',
#  'rank': '64',
#  'singer': 'Kenshi Yonezu',
#  'title': 'Kick Back'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2019/08/omar-apollo-pyf-180x180.jpg',
#  'rank': '65',
#  'singer': 'Omar Apollo',
#  'title': 'Evergreen'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/05/morgan-wallen-nlu-you-proof-503-180x180.jpg',
#  'rank': '66',
#  'singer': 'Morgan Wallen',
#  'title': 'You Proof'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/09/jvke-4lr-goldenhour-qcn-180x180.jpg',
#  'rank': '67',
#  'singer': 'JVKE',
#  'title': 'Golden Hour'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/09/ive-pcg-afterlike-fo9-180x180.jpg',
#  'rank': '68',
#  'singer': 'IVE',
#  'title': 'After Like'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/09/lewis-capaldi-s0e-forgetme-kvv-180x180.jpg',
#  'rank': '69',
#  'singer': 'Lewis Capaldi',
#  'title': 'Forget Me'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2011/11/the-weeknd-xmx-180x180.jpg',
#  'rank': '70',
#  'singer': 'The Weeknd Featuring Daft Punk',
#  'title': 'Starboy'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/08/billie-eilish-lrt-happier-than-ever-xd9-180x180.jpg',
#  'rank': '71',
#  'singer': 'Billie Eilish',
#  'title': 'Happier Than Ever'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/beyonce-0na-break-my-soul-7fc-180x180.jpg',
#  'rank': '72',
#  'singer': 'Beyonce',
#  'title': 'Break My Soul'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2005/11/arctic-monkeys-a3g-106x106.jpg',
#  'rank': '73',
#  'singer': 'Arctic Monkeys',
#  'title': 'I Wanna Be Yours'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/bad-bunny-c3m-180x180.jpg',
#  'rank': '74',
#  'singer': 'Bad Bunny & Jhay Cortez',
#  'title': 'Tarot'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/10/maneskin-ews-theloneliest-6wn-180x180.jpg',
#  'rank': '75',
#  'singer': 'Maneskin',
#  'title': 'The Loneliest'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2020/03/yoasobi-i3g-180x180.jpg',
#  'rank': '76',
#  'singer': 'YOASOBI',
#  'title': 'The Blessing'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2017/02/imagine-dragons-ud7-believer-hmi-180x180.jpg',
#  'rank': '77',
#  'singer': 'Imagine Dragons',
#  'title': 'Believer'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/05/burna-boy-8ej-last-last-t6t-180x180.jpg',
#  'rank': '78',
#  'singer': 'Burna Boy',
#  'title': 'Last Last'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/08/newjeans-9dv-180x180.jpg',
#  'rank': '79',
#  'singer': 'NewJeans',
#  'title': 'Hype Boy'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2005/06/coldplay-bm3-yellow-ty6-180x180.jpg',
#  'rank': '80',
#  'singer': 'Coldplay',
#  'title': 'Yellow'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/public/lazyload-fallback.gif',
#  'rank': '81',
#  'singer': 'Oxlade',
#  'title': 'Ku Lo Sa'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2015/12/ruth-b-6pm-106x106.jpg',
#  'rank': '82',
#  'singer': 'Ruth B.',
#  'title': 'Dandelions'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/07/farruko-lo8-pepas-ymw-180x180.jpg',
#  'rank': '83',
#  'singer': 'Farruko',
#  'title': 'Pepas'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2011/02/ghost-1-lve-180x180.jpg',
#  'rank': '84',
#  'singer': 'Ghost',
#  'title': 'Mary On A Cross'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2009/07/justin-bieber-f8k-180x180.jpg',
#  'rank': '85',
#  'singer': 'Justin Bieber',
#  'title': 'Ghost'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/bad-bunny-c3m-180x180.jpg',
#  'rank': '86',
#  'singer': 'Bad Bunny & Rauw Alejandro',
#  'title': 'Party'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2019/02/lewis-capaldi-s2h-180x180.jpg',
#  'rank': '87',
#  'singer': 'Lewis Capaldi',
#  'title': 'Someone You Loved'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/06/marshmello-dhc-numb-wdt-180x180.jpg',
#  'rank': '88',
#  'singer': 'Marshmello & Khalid',
#  'title': 'Numb'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2006/01/sia-0sp-180x180.jpg',
#  'rank': '89',
#  'singer': 'Sia',
#  'title': 'Unstoppable'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2011/10/lana-del-rey-45t-180x180.jpg',
#  'rank': '90',
#  'singer': 'Lana Del Rey & Cedric Gervais',
#  'title': 'Summertime Sadness'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2018/07/pinkfong-2rz-180x180.jpg',
#  'rank': '91',
#  'singer': 'Pinkfong',
#  'title': 'Baby Shark'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/10/adele-000-easy-on-me-03x-180x180.jpg',
#  'rank': '92',
#  'singer': 'Adele',
#  'title': 'Easy On Me'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/03/camila-cabello-bvl-bam-bam-e5o-180x180.jpg',
#  'rank': '93',
#  'singer': 'Camila Cabello Featuring Ed Sheeran',
#  'title': 'Bam Bam'}
# 2022-10-20 14:10:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2017/01/ed-sheeran-w3r-shape-of-you-0ej-180x180.jpg',
#  'rank': '94',
#  'singer': 'Ed Sheeran',
#  'title': 'Shape Of You'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/1997/04/twice-eu4-180x180.jpg',
#  'rank': '95',
#  'singer': 'TWICE',
#  'title': 'Talk That Talk'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/08/lil-nas-x-qv4-industry-baby-bw6-180x180.jpg',
#  'rank': '96',
#  'singer': 'Lil Nas X & Jack Harlow',
#  'title': 'Industry Baby'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/08/armaniwhite-000-billieeilish-zjv-180x180.jpg',
#  'rank': '97',
#  'singer': 'Armani White',
#  'title': 'Billie Eilish.'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2012/11/sam-smith-ik0-180x180.jpg',
#  'rank': '98',
#  'singer': 'Sam Smith',
#  'title': "I'm Not The Only One"}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/06/baileyzimmerman-qt3-rockandahardplace-zsw-180x180.jpg',
#  'rank': '99',
#  'singer': 'Bailey Zimmerman',
#  'title': 'Rock And A Hard Place'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2005/11/arctic-monkeys-a3g-106x106.jpg',
#  'rank': '100',
#  'singer': 'Arctic Monkeys',
#  'title': '505'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/04/shakira-snl-te-felicito-ncz-180x180.jpg',
#  'rank': '101',
#  'singer': 'Shakira & Rauw Alejandro',
#  'title': 'Te Felicito'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/public/lazyload-fallback.gif',
#  'rank': '102',
#  'singer': 'Pablo Pesadilla x Polima Westcoast x Nicko OG',
#  'title': 'Baby Otaku'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2018/05/billie-eilish-lrt-lovely-hww-180x180.jpg',
#  'rank': '103',
#  'singer': 'Billie Eilish & Khalid',
#  'title': 'Lovely'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2010/07/guns-n-roses-tp2-sweet-child-o-mine-jcn-180x180.jpg',
#  'rank': '104',
#  'singer': "Guns N' Roses",
#  'title': "Sweet Child O' Mine"}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2015/06/post-malone-8b5-180x180.jpg',
#  'rank': '105',
#  'singer': 'Post Malone & Swae Lee',
#  'title': 'Sunflower (Spider-Man: Into The Spider-Verse)'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2019/11/harry-styles-6jk-watermelonsugar-w6n-180x180.jpg',
#  'rank': '106',
#  'singer': 'Harry Styles',
#  'title': 'Watermelon Sugar'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/09/kane-brown-dqa-thankgod-rh9-180x180.jpg',
#  'rank': '107',
#  'singer': 'Kane Brown With Katelyn Brown',
#  'title': 'Thank God'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/public/lazyload-fallback.gif',
#  'rank': '108',
#  'singer': 'Lasso',
#  'title': 'Ojos Marrones'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2018/01/jack-harlow-i43-180x180.jpg',
#  'rank': '109',
#  'singer': 'Jack Harlow',
#  'title': 'First Class'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2013/07/eminem-1xq-180x180.jpg',
#  'rank': '110',
#  'singer': 'Eminem',
#  'title': 'Without Me'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2018/04/calvin-harris-ds5-one-kiss-jk6-180x180.jpg',
#  'rank': '111',
#  'singer': 'Calvin Harris & Dua Lipa',
#  'title': 'One Kiss'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2008/04/lady-gaga-b8x-180x180.jpg',
#  'rank': '112',
#  'singer': 'Lady Gaga & Bradley Cooper',
#  'title': 'Shallow'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2013/11/lizzo-w3u-180x180.jpg',
#  'rank': '113',
#  'singer': 'Lizzo',
#  'title': '2 Be Loved (Am I Ready)'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/public/lazyload-fallback.gif',
#  'rank': '114',
#  'singer': 'Quevedo',
#  'title': 'Vista Al Mar'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/bad-bunny-c3m-180x180.jpg',
#  'rank': '115',
#  'singer': 'Bad Bunny & Tony Dize',
#  'title': 'La Corriente'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/06/ado-27l-newgenesis-vea-180x180.jpg',
#  'rank': '116',
#  'singer': 'Ado',
#  'title': 'New Genesis'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2009/12/j-cole-9on-180x180.jpg',
#  'rank': '117',
#  'singer': 'J. Cole',
#  'title': 'No Role Modelz'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/11/gayle-hce-abcdefu-y97-180x180.jpg',
#  'rank': '118',
#  'singer': 'GAYLE',
#  'title': 'abcdefu'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/public/lazyload-fallback.gif',
#  'rank': '119',
#  'singer': 'Kordhell',
#  'title': 'Murder In My Mind'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2011/11/the-weeknd-xmx-180x180.jpg',
#  'rank': '120',
#  'singer': 'The Weeknd',
#  'title': 'Call Out My Name'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2013/07/arctic-monkeys-a3g-106x106.jpg',
#  'rank': '121',
#  'singer': 'Arctic Monkeys',
#  'title': 'Do I Wanna Know?'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2011/11/the-weeknd-xmx-180x180.jpg',
#  'rank': '122',
#  'singer': 'The Weeknd Featuring Gesaffelstein',
#  'title': 'I Was Never There'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2015/06/post-malone-8b5-180x180.jpg',
#  'rank': '123',
#  'singer': 'Post Malone',
#  'title': 'Circles'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/10/dean-lewis-j7t-howdoisaygoodbye-omz-180x180.jpg',
#  'rank': '124',
#  'singer': 'Dean Lewis',
#  'title': 'How Do I Say Goodbye'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2017/06/oliver-tree-8zt-180x180.jpg',
#  'rank': '125',
#  'singer': 'Oliver Tree & Robin Schulz',
#  'title': 'Miss You'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2008/05/coldplay-bm3-viva-la-vida-oj6-180x180.jpg',
#  'rank': '126',
#  'singer': 'Coldplay',
#  'title': 'Viva La Vida'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2009/10/paloma-faith-sdo-180x180.jpg',
#  'rank': '127',
#  'singer': 'Paloma Faith',
#  'title': 'Only Love Can Hurt Like This'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/beachweather-mo0-180x180.jpg',
#  'rank': '128',
#  'singer': 'Beach Weather',
#  'title': 'Sex, Drugs, Etc.'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/public/lazyload-fallback.gif',
#  'rank': '129',
#  'singer': 'Luar La L',
#  'title': 'Caile'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/public/lazyload-fallback.gif',
#  'rank': '130',
#  'singer': 'Polima WestCoast Featuring Pailita',
#  'title': 'Ultra Solo'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2007/04/onerepublic-m2z-180x180.jpg',
#  'rank': '131',
#  'singer': 'OneRepublic',
#  'title': 'Counting Stars'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2020/04/fujiikaze-cfu-180x180.jpg',
#  'rank': '132',
#  'singer': 'Fujii Kaze',
#  'title': 'Shinunoga E-Wa'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/02/becky-g-gw8-mamiii-azv-180x180.jpg',
#  'rank': '133',
#  'singer': 'Becky G X Karol G',
#  'title': 'MAMIII'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/10/rauwalejandro-rbn-punto40-7il-180x180.jpg',
#  'rank': '134',
#  'singer': 'Rauw Alejandro & Baby Rasta',
#  'title': 'Punto 40'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/12/elley-duhe-w03-106x106.jpg',
#  'rank': '135',
#  'singer': 'Elley Duhe',
#  'title': 'Middle Of The Night'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2019/08/tones-and-i-e1q-dance-monkey-pbf-180x180.jpg',
#  'rank': '136',
#  'singer': 'Tones And I',
#  'title': 'Dance Monkey'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2015/06/the-weeknd-xmx-the-hills-1cr-180x180.jpg',
#  'rank': '137',
#  'singer': 'The Weeknd',
#  'title': 'The Hills'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2020/09/bts-hm9-dynamite-zg6-180x180.jpg',
#  'rank': '138',
#  'singer': 'BTS',
#  'title': 'Dynamite'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/public/lazyload-fallback.gif',
#  'rank': '139',
#  'singer': 'Dedubluman Featuring Mavzer Tabancas',
#  'title': 'Belki'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/01/morgan-wallen-nlu-wasted-on-you-jwj-180x180.jpg',
#  'rank': '140',
#  'singer': 'Morgan Wallen',
#  'title': 'Wasted On You'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/06/bts-hm9-butter-45t-180x180.jpg',
#  'rank': '141',
#  'singer': 'BTS',
#  'title': 'Butter'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2011/04/nirvana-ug8-smells-like-teen-spirit-is8-180x180.jpg',
#  'rank': '142',
#  'singer': 'Nirvana',
#  'title': 'Smells Like Teen Spirit'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/10/lil-yachty-ecx-poland-4vc-180x180.jpg',
#  'rank': '143',
#  'singer': 'Lil Yachty',
#  'title': 'Poland'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/12/steve-lacy-d2o-180x180.jpg',
#  'rank': '144',
#  'singer': 'Steve Lacy',
#  'title': 'Dark Red'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2014/05/hozier-hdg-106x106.jpg',
#  'rank': '145',
#  'singer': 'Hozier',
#  'title': 'Take Me To Church'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/public/lazyload-fallback.gif',
#  'rank': '146',
#  'singer': 'Seafret',
#  'title': 'Atlantis'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2014/10/tears-for-fears-19d-everybody-wants-to-rule-the-world-v61-180x180.jpg',
#  'rank': '147',
#  'singer': 'Tears For Fears',
#  'title': 'Everybody Wants To Rule The World'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/08/newjeans-9dv-180x180.jpg',
#  'rank': '148',
#  'singer': 'NewJeans',
#  'title': 'Attention'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/09/lost-frequencies-e88-where-are-you-now-vlq-180x180.jpg',
#  'rank': '149',
#  'singer': 'Lost Frequencies & Calum Scott',
#  'title': 'Where Are You Now'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2005/02/queen-m21-180x180.jpg',
#  'rank': '150',
#  'singer': 'Queen',
#  'title': 'Bohemian Rhapsody'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/02/50-cent-4gk-in-da-club-znh-180x180.jpg',
#  'rank': '151',
#  'singer': '50 Cent',
#  'title': 'In Da Club'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2003/03/kanye-west-0wf-180x180.jpg',
#  'rank': '152',
#  'singer': 'Kanye West',
#  'title': 'Bound 2'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2013/11/the-chainsmokers-39n-87x87.jpg',
#  'rank': '153',
#  'singer': 'The Chainsmokers & Coldplay',
#  'title': 'Something Just Like This'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2013/10/katy-perry-k49-darkhorse-oa0-180x180.jpg',
#  'rank': '154',
#  'singer': 'Katy Perry Featuring Juicy J',
#  'title': 'Dark Horse'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2010/01/eminem-6zg-lose-yourself-48q-180x180.jpg',
#  'rank': '155',
#  'singer': 'Eminem',
#  'title': 'Lose Yourself'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/03/ckay-eoq-180x180.jpg',
#  'rank': '156',
#  'singer': 'CKay',
#  'title': 'Love Nwantiti (Ah Ah Ah)'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2015/05/bia-1yq-180x180.jpg',
#  'rank': '157',
#  'singer': 'Luciano & Aitch Featuring BIA',
#  'title': 'Bamba'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/public/lazyload-fallback.gif',
#  'rank': '158',
#  'singer': 'Rosa Walton',
#  'title': 'I Really Want To Stay At Your House'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2013/10/a-ha-zrv-takeonme-c5b-180x180.jpg',
#  'rank': '159',
#  'singer': 'a-ha',
#  'title': 'Take On Me'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/05/olivia-rodrigo-3wl-good-4-u-ysx-180x180.jpg',
#  'rank': '160',
#  'singer': 'Olivia Rodrigo',
#  'title': 'Good 4 U'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/11/taylor-swift-5wo-all-too-well-taylors-version-k7x-180x180.jpg',
#  'rank': '161',
#  'singer': 'Taylor Swift',
#  'title': "All Too Well (Taylor's Version)"}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2011/02/the-police-yp0-every-breath-you-take-4oi-180x180.jpg',
#  'rank': '162',
#  'singer': 'The Police',
#  'title': 'Every Breath You Take'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2010/07/j-balvin-i5b-180x180.jpg',
#  'rank': '163',
#  'singer': 'J Balvin & Bad Bunny',
#  'title': 'La Cancion'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2020/11/bad-bunny-c3m-dakiti-wxy-180x180.jpg',
#  'rank': '164',
#  'singer': 'Bad Bunny & Jhay Cortez',
#  'title': 'Dakiti'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2012/07/eminem-6zg-the-real-slim-shady-cbz-180x180.jpg',
#  'rank': '165',
#  'singer': 'Eminem',
#  'title': 'The Real Slim Shady'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/12/rauw-alejandro-rbn-desesperados-n5s-180x180.jpg',
#  'rank': '166',
#  'singer': 'Rauw Alejandro & Chencho Corleone',
#  'title': 'Desesperados'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/10/bad-bunny-c3m-180x180.jpg',
#  'rank': '167',
#  'singer': 'Bad Bunny',
#  'title': 'Despues de La Playa'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2018/04/doja-cat-lm6-180x180.jpg',
#  'rank': '168',
#  'singer': 'Doja Cat',
#  'title': 'Woman'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2015/11/dua-lipa-5k0-180x180.jpg',
#  'rank': '169',
#  'singer': 'Dua Lipa',
#  'title': "Don't Start Now"}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2013/06/cole-swindell-2q7-180x180.jpg',
#  'rank': '170',
#  'singer': 'Cole Swindell',
#  'title': 'She Had Me At Heads Carolina'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2017/11/lilbaby-kyx-180x180.jpg',
#  'rank': '171',
#  'singer': 'Lil Baby',
#  'title': 'Freestyle'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2013/08/vance-joy-578-180x180.jpg',
#  'rank': '172',
#  'singer': 'Vance Joy',
#  'title': 'Riptide'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/public/lazyload-fallback.gif',
#  'rank': '173',
#  'singer': 'natori',
#  'title': 'Overdose'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2005/08/journey-0b3-dontstopbelievin-mvt-180x180.jpg',
#  'rank': '174',
#  'singer': 'Journey',
#  'title': "Don't Stop Believin'"}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/the-black-eyed-peas-f5s-dont-you-worry-sb1-180x180.jpg',
#  'rank': '175',
#  'singer': 'Black Eyed Peas, Shakira + David Guetta',
#  'title': "Don't You Worry"}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2012/12/bruno-mars-va7-180x180.jpg',
#  'rank': '176',
#  'singer': 'Bruno Mars',
#  'title': 'When I Was Your Man'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2006/07/taylor-swift-5wo-180x180.jpg',
#  'rank': '177',
#  'singer': 'Taylor Swift',
#  'title': 'Blank Space'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/feid-ug7-normal-pn7-180x180.jpg',
#  'rank': '178',
#  'singer': 'Feid',
#  'title': 'Normal'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2017/07/cigarettes-after-sex-0oe-180x180.jpg',
#  'rank': '179',
#  'singer': 'Cigarettes After Sex',
#  'title': 'Apocalypse'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2011/05/fleetwood-mac-fe3-dreams-jvb-180x180.jpg',
#  'rank': '180',
#  'singer': 'Fleetwood Mac',
#  'title': 'Dreams'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2004/12/the-killers-7vb-mrbrightside-7k3-180x180.jpg',
#  'rank': '181',
#  'singer': 'The Killers',
#  'title': 'Mr. Brightside'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/1971/10/michael-jackson-9to-180x180.jpg',
#  'rank': '182',
#  'singer': 'Michael Jackson',
#  'title': 'Billie Jean'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2016/12/steve-lacy-d2o-180x180.jpg',
#  'rank': '183',
#  'singer': 'Steve Lacy',
#  'title': 'Static'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2019/04/billie-eilish-lrt-bad-guy-vul-180x180.jpg',
#  'rank': '184',
#  'singer': 'Billie Eilish',
#  'title': 'Bad Guy'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/10/wisin-yandel-cfr-besosmoja2-9u8-180x180.jpg',
#  'rank': '185',
#  'singer': 'Wisin & Yandel + Rosalia',
#  'title': 'Besos Moja2'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2005/02/keane-flj-106x106.jpg',
#  'rank': '186',
#  'singer': 'Keane',
#  'title': 'Somewhere Only We Know'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/1972/06/eagles-ma9-180x180.jpg',
#  'rank': '187',
#  'singer': 'Eagles',
#  'title': 'Hotel California'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2019/06/girl-in-red-j8w-180x180.jpg',
#  'rank': '188',
#  'singer': 'girl in red',
#  'title': 'We Fell In Love In October'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/06/bad-bunny-c3m-yonaguni-zqi-180x180.jpg',
#  'rank': '189',
#  'singer': 'Bad Bunny',
#  'title': 'Yonaguni'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2012/12/ac-dc-3eb-180x180.jpg',
#  'rank': '190',
#  'singer': 'AC/DC',
#  'title': 'Thunderstruck'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/01/olivia-rodrigo-3wl-drivers-license-w08-180x180.jpg',
#  'rank': '191',
#  'singer': 'Olivia Rodrigo',
#  'title': 'Drivers License'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/10/coldplay-bm3-my-universe-68v-180x180.jpg',
#  'rank': '192',
#  'singer': 'Coldplay x BTS',
#  'title': 'My Universe'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2014/05/ajr-yr7-180x180.jpg',
#  'rank': '193',
#  'singer': 'AJR',
#  'title': "World's Smallest Violin"}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/1840/12/imagine-dragons-hy6-180x180.jpg',
#  'rank': '194',
#  'singer': 'Imagine Dragons',
#  'title': 'Thunder'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/09/mrkitty-1g9-180x180.jpg',
#  'rank': '195',
#  'singer': 'Mr.Kitty',
#  'title': 'After Dark'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2021/03/silk-sonic-bruno-mars-and-anderson-paak-qd5-leave-the-door-open-ife-180x180.jpg',
#  'rank': '196',
#  'singer': 'Silk Sonic (Bruno Mars & Anderson .Paak)',
#  'title': 'Leave The Door Open'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/05/imanbek-000-belly-dancer-voa-180x180.jpg',
#  'rank': '197',
#  'singer': 'Imanbek & BYOR',
#  'title': 'Belly Dancer'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2011/07/ed-sheeran-w3r-180x180.jpg',
#  'rank': '198',
#  'singer': 'Ed Sheeran',
#  'title': 'Thinking Out Loud'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2022/07/yunggravy-oae-bettygetmoney-e19-180x180.jpg',
#  'rank': '199',
#  'singer': 'Yung Gravy',
#  'title': 'Betty (Get Money)'}
# 2022-10-20 14:10:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.billboard.com/charts/billboard-global-200/>
# {'img': 'https://charts-static.billboard.com/img/2013/02/macklemore-ryan-lewis-th1-180x180.jpg',
#  'rank': '200',
#  'singer': 'Macklemore & Ryan Lewis Featuring Ray Dalton',
#  'title': "Can't Hold Us"}
# 2022-10-20 14:10:54 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-10-20 14:10:54 [scrapy.extensions.feedexport] INFO: Stored csv feed (200 items) in: billboard.csv
# 2022-10-20 14:10:54 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 472,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 198349,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'elapsed_time_seconds': 2.606861,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 10, 20, 12, 10, 54, 73904),
#  'httpcompression/response_bytes': 3599465,
#  'httpcompression/response_count': 2,
#  'item_scraped_count': 200,
#  'log_count/DEBUG': 205,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 1,
#  'memusage/max': 110948352,
#  'memusage/startup': 110948352,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2022, 10, 20, 12, 10, 51, 467043)}
# 2022-10-20 14:10:54 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
import pandas as pd

df = pd.read_csv('./BillBoard/spiders/billboard.csv')
df
# Out:
#                                                    img  last_position  \
# 0                                                 None            NaN
# 1                                                  img  last_position
# 2    https://charts-static.billboard.com/img/2013/0...            NaN
# 3                                                  img  last_position
# 4    https://charts-static.billboard.com/img/2013/0...            NaN
# ..                                                 ...            ...
# 201  https://charts-static.billboard.com/img/2021/0...            NaN
# 202  https://charts-static.billboard.com/img/2022/0...            NaN
# 203  https://charts-static.billboard.com/img/2011/0...            NaN
# 204  https://charts-static.billboard.com/img/2022/0...            NaN
# 205  https://charts-static.billboard.com/img/2013/0...            NaN
#
#      peak_position  rank                                        singer  \
# 0              NaN   200  Macklemore & Ryan Lewis Featuring Ray Dalton
# 1    peak_position  rank                                        singer
# 2              NaN   200  Macklemore & Ryan Lewis Featuring Ray Dalton
# 3    peak_position  rank                                        singer
# 4              NaN   200  Macklemore & Ryan Lewis Featuring Ray Dalton
# ..             ...   ...                                           ...
# 201            NaN   196      Silk Sonic (Bruno Mars & Anderson .Paak)
# 202            NaN   197                                Imanbek & BYOR
# 203            NaN   198                                    Ed Sheeran
# 204            NaN   199                                    Yung Gravy
# 205            NaN   200  Macklemore & Ryan Lewis Featuring Ray Dalton
#
#                    title  weaks_on_charts
# 0          Can't Hold Us              NaN
# 1                  title  weaks_on_charts
# 2          Can't Hold Us              NaN
# 3                  title  weaks_on_charts
# 4          Can't Hold Us              NaN
# ..                   ...              ...
# 201  Leave The Door Open              NaN
# 202         Belly Dancer              NaN
# 203    Thinking Out Loud              NaN
# 204    Betty (Get Money)              NaN
# 205        Can't Hold Us              NaN
#
# [206 rows x 7 columns]
